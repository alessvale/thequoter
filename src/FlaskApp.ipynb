# %%
from flask import Flask, render_template, jsonify, request
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import os

import html
import urllib.request
import re
import spacy

# %%
with urllib.request.urlopen('https://gist.githubusercontent.com/erickedji/68802/raw/7264f2d232702b4013490a0b2f9286cfa1b817e3/quotes.txt') as f:
    lines = [s.decode('utf-8')  for s in f.readlines()]

# %%
with open("raw.txt", "r") as f:
    text = f.readlines()

# %%
# Out:
# ['"Do-so" is more important than "say-so". â€” Pete Seeger\n',
#  '"Dreamt" is the only English word that ends in the letters "mt".\n',
#  '"For example" is not proof. â€” Yiddish proverb\n',
#  '"I really don\'t believe that, but I was raised that way." â€” Carolyn Myss\n',
#  '"Keep the tourists out..." As fellow tourists we heartily agree. â€” Edward Abbey\n',
#  '"Know thyself"? If I knew myself, I\'d run away. â€” Johann von Goethe\n',
#  '"My country right or wrong" is like saying, "My mother drunk or sober."\n',
#  '"Things" are thieves of time.\n',
#  '...context... â€” Manny Farber\n',
#  '1. Thought is creative. 2. Fear attracts like energy. 3. Love is all there is.\n',
#  'A "jiffy" is an actual unit of time for 1/100th of a second.\n',
#  "A baby is God's opinion that the world should go on. â€” Carl Sandburg\n",
#  'A beggar can never be bankrupt. â€” John Ray\n',
#  'A billion hours ago man had not yet walked on earth.\n',
#  'A bird in the hand is worth two in the bush.\n',
#  'A boss says, "Go!" A leader says, "Let\'s go!" â€” E.M. Kelley\n',
#  'A boy gets to be a man when a man is needed. â€” John Steinbeck\n',
#  "A business without a path to profit isn't a business, it's a hobby. â€” Jason Fried\n",
#  'A candle loses nothing by lighting another candle.\n',
#  'A chain is no stronger than its weakest link.\n',
#  'A child does not need to be parented. He needs to be mothered and fathered.\n',
#  'A city is a large community where people are lonesome together. â€” Prochnow\n',
#  'A civilized society makes swords into decoration. â€” Danny Low\n',
#  'A clash of doctrine is not a disaster; it is an opportunity.\n',
#  'A clever prophet makes sure of the event first.\n',
#  'A closed mouth gathers no foot.\n',
#  'A collection of facts not necessarily science. â€” Henri Poincar\n',
#  'A company is known by the people it keeps.\n',
#  'A compliment is something like a kiss through a veil. â€” Victor Hugo\n',
#  'A confusion of the real with the ideal never goes unpunished. â€” Johann von Goethe\n',
#  'A conspiracy of silence speaks louder than words.\n',
#  'A continuing flow of paper is sufficient to continue the flow of paper. â€” Dyer\n',
#  'A coward dies a thousand deaths, a brave man dies but once.\n',
#  "A critic is a man who knows the way but can't drive the car. â€” Kenneth Tynan\n",
#  'A critic is to an author as a fungus to an oak. â€” Edward Abbey\n',
#  'A crocodile cannot stick out its tongue.\n',
#  'A cult becomes a religion when it begins to kill those outside its membership.\n',
#  'A culture can be no stronger than its strongest myths. â€” James Carse\n',
#  'A cynic is a disappointed lover.\n',
#  'A cynic is a man who knows the price of everything and the value of nothing.\n',
#  'A day without fear changes your life forever. â€” Jerry Stocking\n',
#  'A deceased body harms the mind.\n',
#  'A dime has 118 ridges around the edge.\n',
#  'A disease known is half cured.\n',
#  'A doctor gets no pleasure out of the health of his friends. â€” de Montaigne\n',
#  'A donkey raised among horses is still a donkey.\n',
#  'A drastic change to stay where you are always puts you in a different place.\n',
#  'A dream that is not interpreted is like a letter that is not read. â€” Talmud\n',
#  'A drill is a tool. A hole is a solution.\n',
#  'A dry cough is the trumpeter of death.\n',
#  'A dying man can do nothing easy. â€” Benjamin Franklin\n',
#  'A fair exterior is a silent recommendation.\n',
#  'A family is the difference between a house and a home.\n',
#  'A fault recognized is half corrected.\n',
#  'A feather in hand is better than a bird in the air. â€” George Herbert\n',
#  'A fellow with a closed mind often has an open mouth.\n',
#  'A flood of words over a desert of thought. â€” Simon Bolivar\n',
#  'A fool and his money are soon parted.\n',
#  'A fool and his words are soon parted. â€” William Shenstone\n',
#  'A fool with tool is still a fool.\n',
#  'A foolish consistency is the hobgoblin of little minds. â€” Ralph Emerson\n',
#  'A free society is one where it is safe to be unpopular. â€” Adlai Stevenson\n',
#  'A friend in need is a friend indeed.\n',
#  'A friend is one with whom you dare to be yourself.\n',
#  'A friend to everyone is a friend to no one.\n',
#  'A full belly makes a dull brain.\n',
#  'A full heart should not go where an empty mind leads.\n',
#  'A genius is always on duty; even his dreams are tax deductible. â€” Edward Abbey\n',
#  'A goal is a dream with a deadline. (But do you really need a deadline?)\n',
#  'A god can create a world only by listening. â€” James Carse\n',
#  'A goldfish has a memory span of three seconds.\n',
#  'A good example is the best sermon. â€” H. Jackson Brown\n',
#  'A good memory does not equal pale ink.\n',
#  'A good painter can draw a devil as well as an angel. â€” G. Delamothe\n',
#  'A good philosopher is one who does not take ideas seriously. â€” Edward Abbey\n',
#  'A good plan today is better than a perfect plan tomorrow. â€” Patton\n',
#  'A good supervisor can step on your toes without messing up your shine.\n',
#  'A good tale cannot too often be told. â€” Sir T. More\n',
#  'A good tongue is a good weapon. â€” James Kelly\n',
#  'A good word costs no more than a bad one. â€” B. Googe\n',
#  'A good workman is known by his tools.\n',
#  'A government able to give you all you want can also take away all you have.\n',
#  "A government that robs Peter to pay Paul can always depend on Paul's support.\n",
#  'A grasshopper has 100 more distinct muscles than a human.\n',
#  'A great idea needs landing gear, not just wings.\n',
#  'A great person never reminds us of others.\n',
#  'A great ship asks deep waters. â€” George Herbert\n',
#  'A half-truth is closer to falsehood than to veracity. â€” Abba Eban\n',
#  'A hammer sometimes misses its mark; a bouquet, never.\n',
#  'A handful of friends is worth more than a wagon of gold.\n',
#  'A handful of sand is an anthology of the universe. â€” David McCord\n',
#  'A hard life is a free lesson in poetry. â€” John Taylor\n',
#  'A hard-working farmer has plenty to eat. â€” Solomon\n',
#  'A heavy purse makes a light heart.\n',
#  "A hen is only an egg's way of making another egg. â€” Samuel Butler II\n",
#  'A hermit is a deserter from the army of humanity.\n',
#  'A hero is a man who does what he can. â€” Romain Rolland\n',
#  'A highbrow is a person educated beyond his intelligence. â€” Brander Matthews\n',
#  'A house is a large liability masquerading as a safe asset. â€” Morgan Housel\n',
#  'A house without books is like a room without windows. â€” Horace Mann\n',
#  'A joke breaks no bones.\n',
#  'A journey of a thousand miles must begin with a single step. â€” Lao Tzu\n',
#  'A learned fool is more foolish than an ignorant fool. â€” Molire\n',
#  'A learned man always has wealth within himself.\n',
#  'A leopard cannot change his spots. â€” William Shakespeare\n',
#  'A liar is not believed when he speaks the truth. â€” Cicero\n',
#  'A liar needs a good memory. â€” Quintilian\n',
#  'A lie has a short life, but truth lives on for ever. â€” Solomon\n',
#  'A life without tragedy would not be worth living. â€” Edward Abbey\n',
#  'A likely impossibility is always preferable to an unconvincing possibility.\n',
#  'A little experience often upsets a lot of theory.\n',
#  'A little fire consumes a great wood. â€” Roger Edgeworth\n',
#  'A little inaccuracy saves a world of explanation. â€” C. E. Ayres\n',
#  'A little knowledge can be a ridiculous thing. â€” Scott Adams\n',
#  'A little sunlight is the best disinfectant. â€” Justice Louis Brandeis\n',
#  'A living dog is better than a dead lion. â€” Old Testament\n',
#  'A log may float in a river, but that does not make it a crocodile.\n',
#  'A long life deprives man of his optimism. â€” Ernest Hemingway\n',
#  'A long tongue is a sign of a short hand. â€” George Herbert\n',
#  'A lost ounce of gold may be found, a lost moment of time never.\n',
#  'A love for the land does not necessarily equate with good care of the land.\n',
#  'A loving mate can see the good in you even when you cannot.\n',
#  'A man can do everything with a sword except sit on it. â€” Talleyrand\n',
#  'A man can do no more than he can.\n',
#  'A man can only be young once, but he can be immature forever. â€” Catherine Aird\n',
#  'A man cannot be in two places at the same time.\n',
#  'A man does not look behind the door unless he has stood there himself.\n',
#  "A man doesn't become a failure until he is satisfied with being one. â€” Henry Cate\n",
#  'A man is a lion in his own cause.\n',
#  'A man is known to be mortal by two things, sleep and lust. â€” Francis Bacon\n',
#  'A man is not old until regrets take the place of dreams. â€” John Barrymore\n',
#  'A man is not so soon healed as hurt. â€” Porter\n',
#  'A man may lose his goods for want of demanding them. â€” Thomas Draxe\n',
#  'A man may lose more in an hour than he can get in seven.\n',
#  'A man must not swallow more beliefs than he can digest. â€” Havelock Ellis\n',
#  'A man never becomes an orator if he has anything to say. â€” Finley Dunne\n',
#  'A man who cannot seduce men cannot save them either. â€” Soren Kierkegaard\n',
#  'A man who fears suffering is already suffering from what he fears. â€” Montaigne\n',
#  'A man will never change his mind if he has no mind to change. â€” Trench\n',
#  'A man with two clocks never knows exactly what is the time.\n',
#  'A man without reason is a beast in season. â€” Howell\n',
#  'A man without religion is like a horse without a bridle.\n',
#  'A man wrapped up in himself makes a very small package.\n',
#  "A man's envy alludes to where his ambition fails. â€” William Wall\n",
#  "A man's home is his castle.\n",
#  "A man's library is his map drawn to scale. â€” John Taylor\n",
#  "A man's praise in his own mouth stinks.\n",
#  "A man's soul may be buried under a pile of money. â€” Nathaniel Hawthorne\n",
#  'A mantra is a training device to break you out of your attachments. â€” Ram Dass\n',
#  'A mask tells us more than the face. â€” Oscar Wilde\n',
#  "A mathematician knows how to solve a problem, but can't do it. â€” Milne\n",
#  'A memorandum is written not to inform the reader but to protect the writer.\n',
#  'A mind that is stretched by an idea will never return to its original size.\n',
#  'A mink is just a high-budget weasel.\n',
#  'A miracle is not an event that heals the physical body, but the mind and spirit.\n',
#  "A moment's insight is sometimes worth a life's experience. â€” Oliver Holmes\n",
#  'A moneyless man goes fast through the market. â€” Fuller\n',
#  'A museum is a collection of labels, illustrated by specimens. â€” George Goode\n',
#  'A mushroom cloud has no silver lining.\n',
#  'A nerd is simply someone who thinks exceedingly inside the box. â€” Nassim Taleb\n',
#  'A nuclear war cannot be won and must never be fought. â€” Ronald Reagan\n',
#  'A page of history is worth a volume of logic.\n',
#  'A peaceful man is the first criterion if you want to have a peaceful universe.\n',
#  'A pedestal is as much a prison as any small, confined space. â€” Gloria Steinem\n',
#  'A penalty for hubris is always exacted. â€” Jon Bayh\n',
#  'A pencil with no point needs no eraser.\n',
#  "A person before birth knows exactly what they're buying into. â€” Ram Dass\n",
#  'A person forgives only when he is in the wrong.\n',
#  'A person is just about as big as the things that make him angry.\n',
#  'A person paints with his brains and not with his hands.\n',
#  "A physicist is an atom's way of knowing about atoms. â€” George Wald\n",
#  'A pious man is one who would be an atheist if the king were. â€” la Bruyere\n',
#  "A plagiarist steals a writer's mental children. â€” Isaac Asimov\n",
#  "A plucked goose doesn't lay golden eggs.\n",
#  'A poet is born not made.\n',
#  'A political career brings out the basest qualities in human nature. â€” Bryce\n',
#  'A poor man sells his saucepan to buy something to put in it.\n',
#  'A pound of salt will not sweeten a single cup of tea.\n',
#  "A pragmatist is one who's ideology/theology has failed. â€” Herbert Schlossberg\n",
#  'A prediction is but an explanation in advance. â€” James Carse\n',
#  'A President is impeachable if he attempts to subvert the Constitution. â€” Madison\n',
#  'A private sin is not so prejudicial in the world as a public indecency.\n',
#  'A problem found by appraisal must be found and fixed each time it occurs.\n',
#  'A problem found by solution is gone forever.\n',
#  'A problem is nothing more than a solution in disguise. â€” John Taylor\n',
#  'A productive drunk is the bane of moralists.\n',
#  'A professorship of theology should have no place in our institution. â€” Thomas Jefferson\n',
#  'A project not worth doing at all is not worth doing well.\n',
#  'A proliferation of theories is a symptom of a lack of data. â€” Eddington\n',
#  'A prophet is not without honor save in his own country. â€” New Testament\n',
#  'A prosperous fool is a grievous burden. â€” Aeschylus\n',
#  'A proverb is a short sentence based on long experience. â€” Miguel de Cervantes\n',
#  'A prudent question is one-half of wisdom. â€” Bacon\n',
#  'A quiet conscience sleeps in thunder.\n',
#  'A real friend walks in when the rest of the world walks out.\n',
#  'A relationship cannot be healthier than both people.\n',
#  'A Renaissance man refuses to define himself.\n',
#  'A rich person is not one who has the most, but one who needs the least.\n',
#  'A ringing telephone is a request, not an order.\n',
#  'A rising tide lifts all boats. â€” Sean Lemass\n',
#  'A rolling stone gathers no moss. â€” Publilius Syrus\n',
#  'A scientist looking at nonscientific problems is just as dumb as the next guy.\n',
#  'A scientist must be successful and not a success-fool. â€” Gerhard Uhlenbruck\n',
#  'A second class effort is a first class mistake.\n',
#  'A second fault ought not to be pardoned. â€” G. Delamothe\n',
#  'A secret is too little for one, enough for two, too much for three.\n',
#  'A sense of humor is just common sense, dancing. â€” Clive James\n',
#  'A serious work in philosophy could be written that consisted entirely of jokes.\n',
#  'A ship on the beach is a lighthouse to the sea. â€” Dutch proverb\n',
#  'A short prayer penetrates heaven.\n',
#  'A single death is a tragedy, a million deaths is a statistic. â€” Joseph Stalin\n',
#  'A slave is one who waits for someone to come and free him. â€” Ezra Pound\n',
#  'A small fire makes often a great smoke. â€” G. Delamothe\n',
#  'A small leak will sink a great ship. â€” Benjamin Franklin\n',
#  'A smooth sea never made a skilled sailor. â€” Franklin D. Roosevelt\n',
#  'A snowflake near lightspeed completely obliterates a planet, even Jupiter. â€” Axel Emmermann\n',
#  'A standard that no one follows is worse than useless; it is a waste of time.\n',
#  'A stitch in time saves nine.\n',
#  'A straight stick is crooked in the water.\n',
#  "A straw vote only shows which way the hot air blows. â€” O'Henry\n",
#  'A stupid person cannot be advised. â€” Lawrence Hirsch\n',
#  'A system meant for common use should rarely need uncommon knowledge. â€” Redford\n',
#  'A tale never loses in the telling.\n',
#  'A teacher affects eternity. â€” Henry Adams\n',
#  'A thief passes for a gentleman when stealing has made him rich. â€” Fuller\n',
#  'A thing is not necessarily true because a man dies for it.\n',
#  'A thing is not true for you until it is true in thought, word, and deed. â€” God?\n',
#  'A third party cannot mediate a dispute if they are even subtley involved.\n',
#  'A thought is often original, though you have uttered it a hundred times.\n',
#  'A tree is known by its fruit. â€” New Testament\n',
#  'A tribe is a group of people who honor the same perceptions. â€” Carolyn Myss\n',
#  'A true leader cannot make anyone do something they do not want to do. â€” Sir Chris Bonington\n',
#  'A true sign of wealth is free time â€” freedom from drudgery. â€” Daniel Newman\n',
#  "A truth that's told with bad intent beats all the lies you can invent. â€” Blake\n",
#  'A violent man will die a violent death. â€” Lao Tsu\n',
#  'A vision is only as good as the clarity of the image presented. â€” TWendle\n',
#  'A wealth of information creates a poverty of attention. â€” Herbert Simon\n',
#  'A weed is a plant whose virtues have not been discovered. â€” Ralph Emerson\n',
#  'A wise lover values not so much the gift of the lover as the love of the giver.\n',
#  'A wise man cares not for what he cannot have. â€” George Herbert\n',
#  'A wise man is never surprised. â€” Horace\n',
#  'A wise person makes his own decisions, a weak one obeys public opinion.\n',
#  'A witty saying proves nothing. â€” Voltaire\n',
#  'A woman is as old as she looks before breakfast. â€” E. W. Howe\n',
#  'A woman is as old as she looks to a man who likes to look at her. â€” Finley Dunne\n',
#  'A woman is as young as she feels like telling you she is.\n',
#  "A woman never forgets the men she could have had; a man, the women he couldn't.\n",
#  'A woman without a man is like a fish without a bicycle. â€” Gloria Steinem\n',
#  'A word in time is worth two afterwards. â€” James Carmichaell\n',
#  'A word to the wise is enough. â€” Miguel de Cervantes\n',
#  'A writer must not shift your point of view. â€” William Safire\n',
#  'A writer without an audience is a writer; a writer with an audience, very lucky.\n',
#  'A yawn is a silent shout. â€” G. K. Chesterton\n',
#  'A young man might have more money than brains â€” but not for long!\n',
#  'A [person] without religion is like a fish without pajamas. â€” J. Powers\n',
#  'Ability has nothing to do with opportunity. â€” Napoleon\n',
#  'Above all things, reverence yourself.\n',
#  'Absence makes the heart grow fonder. â€” Sextus Propertius\n',
#  'Absence of evidence is not evidence of absence.\n',
#  'Absence sharpens love. Presence strengthens it. â€” Thomas Fuller\n',
#  'Absence works wonders. â€” Tottel\n',
#  'Abstraction is representing the whole by a part of the whole.\n',
#  'Accept forgiveness as a way of life.\n',
#  'Accept loneliness as normal, merely a sign that action is required. â€” Will Limon\n',
#  'Accept your ordination. â€” Carolyn Myss\n',
#  'Achilles cannot defeat the tortoise if he thinks of space and time. â€” Valery\n',
#  'Action is what separates an opinion from a belief. â€” Patel\n',
#  'Action makes more fortune than caution.\n',
#  'Action may not always bring happiness, but there is no happiness without action.\n',
#  'Actions speak louder than words. â€” Confucius\n',
#  'Ad astra per aspera. (To the stars through hardships.)\n',
#  'Adaptation precludes adaptivity. â€” Carl White\n',
#  'Adde parvum parvo magnus acervus erit. (Add little to little, get big pile.)\n',
#  "Addiction is an adaptation. It's not you. It's your cage. â€” Bruce Alexander\n",
#  'Admit it, unplug, and get it over with. â€” Carolyn Myss\n',
#  "Adolf Hitler made a mistake admiring Napoleon's strategy.\n",
#  'Adversity introduces man to himself.\n',
#  'Adversity makes a man wise, not rich. â€” John Ray\n',
#  'Advice from an old carpenter: Measure twice, saw once.\n',
#  'Advice is a dangerous gift; be cautious about giving and receiving it.\n',
#  'Advice is a form of nostalgia. â€” Mary Schmich\n',
#  'Advice is least heeded when most needed.\n',
#  'Advice only works for the people that give it. â€” Scott Adams\n',
#  'Advocacy addiction limits our ability to learn from others; use inquiry instead.\n',
#  'Affection blinds reason. â€” J. Howell\n',
#  'Affection makes a fool of any man. â€” Ben Jonson\n',
#  'After a calm comes a storm. â€” Thomas Draxe\n',
#  'After a storm comes a calm.\n',
#  'After age 30, we are all in extra innings. â€” Alan Silverstein\n',
#  'After dinner sit awhile, after supper walk a mile. â€” Whetstone\n',
#  'After enlightenment, do the laundry. â€” Zen proverb\n',
#  'After pleasure comes pain. â€” J. C. Bridge\n',
#  'After the game, the king and the pawn go in the same box. â€” Italian proverb\n',
#  'Age before beauty; and pearls before swine. â€” Dorothy Parker\n',
#  'Age does not protect you from love, but love somewhat protects you from age.\n',
#  "Age doesn't always bring wisdom. Sometimes age comes alone.\n",
#  'Age is a high price to pay for maturity.\n',
#  'Age is like love, it cannot be hid. â€” Dekker\n',
#  "All are given the key to heaven's gates; the same key opens the gates of hell.\n",
#  'All are not merry that dance lightly.\n',
#  'All are not thieves that dogs bark at.\n',
#  'All art is but imitation of nature. â€” Seneca\n',
#  'All clouds bring not rain.\n',
#  'All dreams are possible until proven otherwise. â€” Kenny Loggins\n',
#  'All education is accompanied by pain. â€” Aristotle\n',
#  'All finite play is play against itself. â€” James Carse\n',
#  'All forms of government are pernicious, including good government. â€” Edward Abbey\n',
#  'All generalizations are dangerous, even this one. â€” Dumas\n',
#  "All gold is fool's gold. â€” Edward Abbey\n",
#  'All good work is done in defiance of management. â€” Tom Peters\n',
#  'All governments need enemies. How else to justify their existence? â€” Edward Abbey\n',
#  'All great discoveries are made by mistake. â€” Young\n',
#  'All great discoveries have been made from a willingness to not be right. â€” God?\n',
#  'All great ideas are controversial, or have been at one time.\n',
#  'All great truths begin as blasphemies. â€” George Shaw\n',
#  'All hope abandon, ye who enter here! â€” Dante Alighieri\n',
#  'All I ask of you is forever to remember me as loving you.\n',
#  'All I know is, I will get guidance when I need it. â€” Carolyn Myss\n',
#  'All I need to do is change one attitude and that is enough to change my world.\n',
#  'All I want from you is your joyful sharing. â€” Lee Coit\n',
#  "All in all, it's just another brick in the wall.\n",
#  'All inventions are force multipliers.\n',
#  'All is fair in love and war.\n',
#  'All is not gold that glitters.\n',
#  'All is not lost that is delayed. â€” A. Boyer\n',
#  'All is well that ends well. â€” John Heywood\n',
#  'All laws are simulations of reality. â€” John C. Lilly\n',
#  'All life evolves by the differential survival of replicating entities. â€” Richard Dawkins\n',
#  'All limits must be zero, one, or infinite.\n',
#  'All machines are amplifiers.\n',
#  'All may begin a war, few can end it.\n',
#  'All men are mortal. â€” Haughton\n',
#  'All men know the utility of useful things, but know not the utility of futility.\n',
#  'All modern thought is permeated by the idea of thinking the unthinkable.\n',
#  'All my life I wanted to be someone; I should have been more specific. â€” Wagner\n',
#  'All obstacles not foreseen will be tripped over.\n',
#  'All pain other than physical arises from failed expectations.\n',
#  'All people smile in the same language.\n',
#  'All philosophy lies in two words: Sustain and abstain. â€” Epictetus\n',
#  'All professions are organized conspiracies against the laity. â€” Russell\n',
#  'All progress depends on the unreasonable man. â€” George Shaw\n',
#  'All relationship is a mirror of your relationship with yourself. â€” Deepak Chopra\n',
#  'All roads in the Middle East lead to the bizarre. â€” John Chanselor\n',
#  'All roads lead to Rome. â€” La Fontaine\n',
#  'All that is said in the kitchen should not be heard in the hall.\n',
#  'All that we may see or seem, is but a dream within a dream. â€” Edgar Allan Poe\n',
#  "All the world's churchyards are full with irreplaceable people.\n",
#  'All things are good untried. â€” James Carmichaell\n',
#  'All things come to he who waits.\n',
#  'All things excellent are as difficult as they are rare.\n',
#  'All things merge into one, and a river runs through it. â€” Norman McLain\n',
#  'All things obey money. â€” Guazzo\n',
#  'All truth, like love, is eternal â€” while it lasts. â€” William Etkin\n',
#  'All wars are civil wars, because all men are brothers... â€” Francois Fenelon\n',
#  'All we learn from history is that we learn nothing from history. â€” Hegel\n',
#  'All you accomplish by defending someone is to concede that he needs a defense.\n',
#  'All you have to offer another human being, ever, is your own state of being.\n',
#  'All you need in this life is ignorance and confidence, and then success is sure.\n',
#  'All your fears must be embraced, entertained, honored, and you go on with them.\n',
#  'Allow each soul to walk its path. â€” Conversations with God\n',
#  'Allow others to make educational mistakes.\n',
#  'Allow your children to face the consequences of their actions. â€” Brown\n',
#  'Almost everything is easier to get into than out of.\n',
#  "Almost everything looks better after a good night's sleep. â€” H. Jackson Brown\n",
#  'Almost was never hanged. â€” Roger Edgeworth\n',
#  'Alternatives exclude. Saying "yes" to one thing says "no" to another. â€” Neifert\n',
#  'Always be careful to make a bad impression on undesirables.\n',
#  'Always do what you are afraid to do. â€” Emerson\n',
#  'Always find time for that which makes you happy to be alive.\n',
#  'Always the dullness of the fool is the whetstone of the wits.\n',
#  'Amateurs talk strategy while generals talk logistics.\n',
#  'Ambition is the last refuge of the failure. â€” Oscar Wilde\n',
#  "America's best buy for a nickel is a telephone call to the right person.\n",
#  'Americans are people who insist on living in the present, tense.\n',
#  'Americans do the right thing, but only after exhausting all other possibilities. â€” Winston Churchill\n',
#  "An addict bonds with heroin because he can't bond as fully with anything else.\n",
#  'An American is a man with two arms and four wheels. â€” A Chinese child\n',
#  'An aphorism is a one-line novel. â€” Leonid Sukhorukov\n',
#  'An apple a day keeps the doctor away.\n',
#  'An argument is the longest distance between two points.\n',
#  'An armed society is a polite society.\n',
#  'An army is nothing but a well-organized lynch mob. â€” Edward Abbey\n',
#  'An army marches on its stomach. â€” Napoleon\n',
#  'An artist who is self-taught is taught by a very ignorant person indeed.\n',
#  'An atheist is one point beyond the devil. â€” Fuller\n',
#  'An atom-blaster is a good weapon, but it can point both ways.\n',
#  'An average person laughs about 15 times a day.\n',
#  'An easy answer to every human problem: Neat, plausible, and wrong. â€” Mencken\n',
#  'An efficient bureaucracy is the greatest threat to liberty. â€” Eugene McCarthy\n',
#  'An egg today is better than a hen tomorrow. â€” Benjamin Franklin\n',
#  'An ego trip takes you nowhere.\n',
#  'An emotionless life is biologically impossible. â€” Lawrence Hirsch\n',
#  'An empty man is full of himself. â€” Edward Abbey\n',
#  'An empty purse fills the face with wrinkles. â€” Thomas Draxe\n',
#  'An empty stomach is not a good political advisor. â€” Albert Einstein\n',
#  "An enduring paradox of the human mind is that it doesn't know itself very well.\n",
#  'An era can be said to end when its basic illusions are exhausted. â€” Miller\n',
#  'An expert is a person who knows his limitations.\n',
#  'An expert is an ordinary guy 50 miles from home.\n',
#  'An expert knows no more than you do, but has it better organized.\n',
#  'An eye for an eye, a tooth for a tooth.\n',
#  'An honest answer is a sign of true friendship. â€” Solomon\n',
#  "An honest man's the noblest work of God. â€” Alexander Pope\n",
#  'An honest tale speeds best being plainly told.\n',
#  'An idea is not responsible for the people who believe in it.\n',
#  'An idea is only as good as its execution.\n',
#  'An idea well-expressed is like a design of gold, set in silver. â€” Solomon\n',
#  'An idealist is a person who helps other people to be prosperous. â€” Henry Ford\n',
#  "An idle brain is the devil's shop. â€” W. Perkins\n",
#  'An incorrect belief may still benefit its believer.\n',
#  'An intellectual is someone whose mind watches itself. â€” Albert Camus\n',
#  'An investment in knowledge always pays the best interest. â€” Benjamin Franklin\n',
#  'An occasion lost cannot be redeemed. â€” John Ray\n',
#  'An open auction extracts the highest price from any buyer.\n',
#  'An optimist laughs to forget; a pessimist forgets to laugh.\n',
#  'An ounce of application is worth a ton of abstraction. â€” Booker\n',
#  'An ounce of clear truth is worth a pound of obfuscation.\n',
#  'An ounce of emotion equals a ton of facts.\n',
#  'An ounce of good fortune is worth a pound of forecast. â€” Fuller\n',
#  'An ounce of vanity can ruin a ton of merit.\n',
#  'An owl is the king of the night. â€” Thomas Draxe\n',
#  'An ox is taken by the horns, and a man by the tongue.\n',
#  'Analogies prove nothing... But they can make one feel at home. â€” Freud\n',
#  "And malt does more than Milton can to justify God's ways to man. â€” Housman\n",
#  'And only the good die young. â€” Billy Joel\n',
#  "And that's the way it is... â€” Walter Cronkite\n",
#  'And tomorrow will be like today, only more so. â€” Isaiah 56:12 [NSV]\n',
#  'Angels do not support BS. â€” Carolyn Myss\n',
#  'Anger goes after the first available target. â€” Reggie Rivers\n',
#  'Anger is a short madness. â€” Taverner\n',
#  'Anger kills as surely as the other vices.\n',
#  'Animals cannot be harvested. They mature, but they do not ripen. â€” James Carse\n',
#  'Another such victory over the Romans, and we are undone. â€” Pyrrhus\n',
#  'Answers almost never fulfill the promise of our questions. â€” John Taylor\n',
#  'Anxiety is a condition of the privileged.\n',
#  'Any clod can have the facts, but having opinions is an art. â€” Charles McCabe\n',
#  'Any difference that makes a difference is information. â€” Gregory Bateson\n',
#  'Any difference that makes no difference is noise. â€” Gregory Bateson\n',
#  "Any doom that can be predicted won't happen. â€” Scott Adams\n",
#  'Any excuse will serve a tyrant. â€” Aesop\n',
#  'Any fool can criticize, condemn, and complain â€” and most fools do. â€” Carnegie\n',
#  'Any fool can make a rule and every fool will mind it. â€” Thoreau\n',
#  'Any fool can paint a picture, but it takes a wise person to be able to sell it.\n',
#  'Any illusion requires both time and space to be experienced.\n',
#  'Any man who thinks of himself as therapy should not have a license to practice.\n',
#  'Any negativity can make you sick. â€” Carolyn Myss\n',
#  'Any new tax law must exempt enough voters to win the next election.\n',
#  'Any philosophy that can be put in a nutshell belongs there. â€” Harris\n',
#  'Any reality that you get stuck in is the wrong one. â€” Ram Dass\n',
#  'Any sufficiently advanced technology is indistinguishable from magic. â€” Arthur Clarke\n',
#  'Any system that depends on reliability is unreliable.\n',
#  "Any technology distinguishable from magic is insufficiently advanced. â€” Gehm's corollary\n",
#  'Any time that you crave, there is always going to be suffering built right in.\n',
#  'Anyone can hold the helm when the sea is calm. â€” Publilius Syrus\n',
#  'Anyone can make history. Only a great man can write it. â€” Oscar Wilde\n',
#  'Anyone can make mistakes, but only an idiot persists in his error. â€” Cicero\n',
#  'Anyone may arrange his affairs so that his taxes shall be as low as possible. â€” Judge Learned Hand\n',
#  'Anyone who wants to rule, should, ipso facto, not be allowed to do so.\n',
#  'Anyone without a sense of humor is at the mercy of everyone else. â€” Rotsler\n',
#  'Anything free comes with no guarantee.\n',
#  'Anything free is worth what you pay for it.\n',
#  'Anything is easy if someone else does it for you.\n',
#  'Anything is easy if you can assimilate it to your collection of models. â€” Papert\n',
#  "Anything is possible if you don't know what you're talking about.\n",
#  'Anything is possible, but only a few things actually happen. â€” Rich Rosen\n',
#  'Anything is possible, unless it is not.\n',
#  'Anything that sticks out usually gets hammered back in.\n',
#  'Apparently there are multiple way sto invoke multiple universes.\n',
#  'Appearance VERSUS reality? Appearance IS reality... â€” Edward Abbey\n',
#  'Appearances often are deceiving. â€” Aesop\n',
#  'Apply good consumerism to your love relationships. â€” Will Limon\n',
#  'Approach your limits from the safe side. â€” Volker Hetzer\n',
#  'Architecture is frozen music. â€” Hegel\n',
#  'Argue for your limitations and sure enough, they are yours. â€” Richard Bach\n',
#  'Armed with these patterns, we go forward and brilliantly predict... the past. â€” Allan Roth\n',
#  'Art has no enemy but ignorance. â€” Ben Jonson\n',
#  'Art is a lie that makes us realize the truth. â€” Picasso\n',
#  'Art is never finished, only abandoned. â€” Leonardo da Vinci\n',
#  'Artistic temperament is a disease that afflicts amateurs. â€” G. K. Chesterton\n',
#  'As a man lives, so shall he die; as a tree falls, so shall it lie.\n',
#  'As a rule, pantheism is only a respectful variety of atheism. â€” Schopenhauer\n',
#  "As average skill increases, it's more difficult to outperform by large margins. â€” Larry Swedroe\n",
#  "As far as the question of Martian life, if we don't go, we won't know. â€” Robert Zubrin\n",
#  'As for the future, your task is not to foresee, but to enable it.\n',
#  'As goatherd learns his trade by goat, so writer learns his trade by wrote.\n',
#  'As is the mother, so is her daughter. â€” Old Testament\n',
#  'As life is to live, so love is to give. â€” Patricia Barc\n',
#  'As others hurt and betray us, so are we the perpetrators of pain. â€” Will Limon\n',
#  'As silent as the grave. â€” Robert Stevenson\n',
#  'As soon as man is born he begins to die.\n',
#  'As the area of your knowledge grows, so does the perimeter of your ignorance. â€” Neil Tyson\n',
#  'As the body becomes more limited, the soul expands. â€” Dustin Hoffman\n',
#  'As the question, so the answer. â€” Torriano\n',
#  'As the radius of knowledge increases, so does the circumference of ignorance.\n',
#  'As we let our own light shine, we give others permission to do the same.\n',
#  'As we migrated into Europe we discovered something new, called winter. â€” Paul Stamets\n',
#  "Ashes to ashes, dust to dust; if God won't have you, the devil must.\n",
#  'Ask a self-answering question; get a self-questioning answer. â€” John Flagg\n',
#  'Ask much to have little.\n',
#  'Ask no questions and you will be told no lies. â€” Charles Dickens\n',
#  'Ask not for whom the bell tolls; it tolls for thee. â€” John Donne\n',
#  "Ask not what's inside your head, but what your head's inside of. â€” Gibson\n",
#  'Ask yourself whether you are happy and you cease to be so. â€” John Mill\n',
#  'Assertiveness is essential to a healthy relationship.\n',
#  'Assume the worst, hope for the best, accept reality. â€” Morgan Housel\n',
#  'Assumption is the mother of all screw-ups. â€” Wethern\n',
#  'Asteroids are nature\'s way of asking, "How\'s that space program coming along?"\n',
#  'Astrology is true, but the astrologers cannot find it. â€” George Herbert\n',
#  'At 50, everyone has the face he deserves. â€” George Orwell\n',
#  'At either end of the social spectrum there lies a leisure class. â€” Beck\n',
#  'At four we know all the questions. At eighteen we know all the answers.\n',
#  'At retirement, human capital falls to zero. â€” Pfau and Kitces\n',
#  'At the feast of ego, everyone leaves hungry.\n',
#  'At the moment of meeting, the parting begins.\n',
#  'Attachments fall away like a snake sheds its skin. â€” Ram Dass\n',
#  'Attack the problem, not each other. â€” Will Limon\n',
#  'Auribus teneo lupum. (I hold a wolf by the ears.)\n',
#  'Authority should command respect, not demand respect.\n',
#  'Autocracy is based on the theorem that one man is smarter than many.\n',
#  'Autograph your work with quality.\n',
#  'Avert misunderstanding by calm, poise, and balance.\n',
#  'Avoid unnecessary dependency on large scale, harmful predictions. â€” Nassim Taleb\n',
#  'Avoidable complexity should indeed be avoided.\n',
#  'Avoiding danger is no safer in the long run than outright exposure to it.\n',
#  'Bad is never good until worse happens. â€” Danish proverb\n',
#  'Bad money drives out good money; new love drives out old love.\n',
#  'Barbarian: Thinks the customs of his tribe and island are laws of nature.\n',
#  'Barking dogs seldom bite.\n',
#  'Be a Fundamentalist â€” ensure the Fun always comes before the mental. â€” Bhaerman\n',
#  "Be a good listener 'cause you never learn much from talking. â€” Will Rogers\n",
#  'Be a light unto the darkness, and curse it not. â€” Conversations with God\n',
#  'Be agreeable in manner, and resolute in action. â€” Lord Chesterfield\n',
#  "Be an expert on what's strong, not on what's wrong. â€” Will Limon\n",
#  'Be ashamed to die until you have won one victory for humanity. â€” Horace Mann\n',
#  'Be bold in what you stand for and careful what you fall for. â€” Mary Webb\n',
#  'Be both a speaker of words and a doer of deeds. â€” Homer\n',
#  'Be careful about what you teach your children. They might believe you.\n',
#  'Be careful what you plug yourself into. â€” Carolyn Myss\n',
#  'Be careful whose advice you buy, but be patient with those who supply it.\n',
#  'Be cheerful while you are alive.\n',
#  'Be conservative in what you generate, but liberal in what you accept.\n',
#  "Be emotionally prepared to walk away from any deal that doesn't work for you.\n",
#  "Be faithful to that which exists nowhere but in yourself. â€” Andre Gide'\n",
#  'Be fearful when others are greedy, and greedy when others are fearful. â€” Warren Buffett\n',
#  'Be good and you will be lonesome. â€” Mark Twain\n',
#  'Be happy with the real pleasures in life.\n',
#  'Be humble or you will stumble.\n',
#  'Be in the world but not of it. â€” Meher Baba\n',
#  'Be kind and courteous to everyone. â€” Peter Chantilis\n',
#  'Be moderate where pleasure is concerned, avoid fatigue.\n',
#  "Be nice to people on your way up; you'll meet them on your way down. â€” Mizner\n",
#  'Be not anxious about what you have, but about what you are. â€” St. Gregory I\n',
#  'Be not simply good â€” be good for something. â€” Henry Thoreau\n',
#  'Be organized: This is a euphemism for being efficiently lazy. â€” Isaac Asimov\n',
#  'Be self-reliant and your success is assured.\n',
#  'Be spontaneous!\n',
#  'Be sure your ladder of success is leaning against the right wall. â€” Dobson\n',
#  'Be the most positive person you know.\n',
#  'Be thou familiar, but by no means vulgar. â€” William Shakespeare\n',
#  "Be to friends' virtues very kind; be to their faults a little blind.\n",
#  'Be willing to lead your life, not just follow it.\n',
#  'Beauty and chastity seldom agree.\n',
#  'Beauty fades like a flower.\n',
#  'Beauty has nothing to do with the package I come in; it is just what I radiate.\n',
#  'Beauty is in the eye of the beholder.\n',
#  'Beauty is one of the rare things which do not lead to doubt of God. â€” Anouilh\n',
#  'Beauty is potent but money is omnipotent.\n',
#  'Beauty may have fair leaves, yet bitter fruit. â€” Lyly\n',
#  "Beauty that doesn't make a woman vain makes her very beautiful. â€” Josh Billings\n",
#  "Because we don't think about future generations, they will never forget us.\n",
#  'Become famous for finishing important, difficult tasks. â€” H. Jackson Brown\n',
#  'Becoming number one is easier than remaining number one. â€” Senator Bill Bradley\n',
#  'Before borrowing money from a friend, decide which you need more. â€” Hallock\n',
#  'Before buying a piece of property, walk around its perimeter.\n',
#  'Before thirty, men seek disease; after thirty, diseases seek men. â€” Chinese\n',
#  "Before Xerox, five carbons were the maximum extension of anyone's ego.\n",
#  'Before you accuse, walk a mile in their shoes.\n',
#  'Before you kill the cat, make arrangements for the mice. â€” Sufi proverb\n',
#  'Beg from beggars and you will never be rich.\n',
#  'Beggars cannot be choosers.\n',
#  'Begin a lesson with a humorous illustration. â€” the Talmud\n',
#  'Begin well, end badly; begin badly, end worse.\n',
#  "Behaviors don't continue unless we get something for them, even just attention.\n",
#  'Behind all individual differences there turns out to be only one of us.\n',
#  "Behind every argument is someone's ignorance.\n",
#  'Being brave does not mean going out looking for trouble.\n',
#  'Being consistent is less important than being happy. â€” Marlo Thomas\n',
#  'Being defeated is often a temporary condition. Giving up makes it permanent.\n',
#  'Being deserving of praise blinds us to flattery. â€” William Wall\n',
#  'Being flexible is how you exercise your adult part.\n',
#  'Being human involves becoming a burden. â€” Roy Bonisteel\n',
#  'Being lazy will make you poor, but hard work will make you rich. â€” Solomon\n',
#  'Being on sea, sail; being on land, settle. â€” George Herbert\n',
#  'Being part of the tribal mind is part of your evolution. â€” Carolyn Myss\n',
#  'Being predictable in your style puts you at the mercy of your adversary.\n',
#  'Being right is seldom enough. Even the best ideas must be packaged and sold.\n',
#  'Belief in God? An afterlife? I believe in rock... â€” Edward Abbey\n',
#  'Belief in the supernatural reflects a failure of the imagination. â€” Edward Abbey\n',
#  'Belief is not the beginning but the end of all knowledge. â€” Johann von Goethe\n',
#  'Believe and ye shall receive.\n',
#  'Believe only half of what you see, and nothing that you hear. â€” Mulock\n',
#  'Believe that life is worth living and your belief will help create the fact.\n',
#  'Believing God created it all is religion. Wondering how it works is science.\n',
#  'Best is best cheap. â€” Wolcot\n',
#  'Best to bend it while it is a twig.\n',
#  'Better a cruel truth than a comfortable delusion. â€” Edward Abbey\n',
#  'Better a diamond with a flaw than a pebble without. â€” Chinese proverb\n',
#  'Better a lean peace than a fat victory. â€” Sanford\n',
#  'Better a little loss than a long sorrow. â€” Langland\n',
#  'Better an open enemy than a false friend.\n',
#  'Better clean death than dirty life. â€” Frank Herbert\n',
#  'Better late than never. â€” Titus Livius\n',
#  'Better living a beggar than buried an emperor.\n',
#  'Better safe than sorry.\n',
#  'Better some of a pudding than none of a pie. â€” John Ray\n',
#  "Better the devil you know than the devil you don't know.\n",
#  'Better the foot slip than the tongue. â€” Sanford\n',
#  'Better to be ignorant of a matter than half know it. â€” Publilius Syrus\n',
#  'Better to be patient on the road than a patient in the hospital. â€” C. Jenkins\n',
#  'Better to be poor and fear the Lord than to be rich and in trouble. â€” Solomon\n',
#  'Better to be the head of an ass than the tail of a horse. â€” Clarke\n',
#  'Better to reign in Hell then serve in Heaven. â€” Milton\n',
#  'Better to remain silent and be thought a fool than speak and remove all doubt.\n',
#  'Better to understand a little than to misunderstand a lot.\n',
#  'Better untaught than ill taught. â€” John Ray\n',
#  'Between a good reputation and great wealth, choose a good reputation. â€” Solomon\n',
#  'Beware of all enterprises that require new clothes... â€” Henry Thoreau\n',
#  'Beware of the man of one book. â€” George Herbert\n',
#  'Beware of the man who has no enemies. â€” Edward Abbey\n',
#  'Beware of the man who knows the answer before he understands the question.\n',
#  'Beware of your wishes: They will probably come true. â€” Edward Abbey\n',
#  'Beware substantiation of abstracta, which leads to fallacies.\n',
#  'Beware temptation â€” the more of it you see, the better it looks.\n',
#  'Beware the legless man who teaches running.\n',
#  'Beware the wrath of a patient person.\n',
#  "Beware those who cannot tell God's will from their own. â€” Barbara Taylor\n",
#  "Big brother isn't watching you, you're watching big brother â€” all 181 channels.\n",
#  "Bigger isn't always better, but better will always get bigger. â€” Kevin Jones\n",
#  'Biochemistry is the study of carbon compounds that crawl. â€” Mike Adams\n',
#  'Birds of a feather flock together.\n',
#  'Bizarreness is the essence of the exotic.\n',
#  'Blessed is he who expects nothing, for he shall never be disappointed. â€” Pope\n',
#  'Blessings on him that invented sleep! â€” Cervantes\n',
#  'Blinding speed can compensate for a lot of deficiencies. â€” David Nichols\n',
#  'Blood is thicker than water.\n',
#  'Boldness has genius, power, and magic in it.\n',
#  'Books as well as food nourish and warm people. Books make connections. â€” Sarton\n',
#  'Boredom: The desire for desires. â€” Leo Tolstoi\n',
#  'Borrowed garments never fit well. â€” Fuller\n',
#  'Boys will be boys.\n',
#  'Break a few rules.\n',
#  'Brevity is the soul of wit.\n',
#  'Build a better mousetrap and the world will beat a path to your door.\n',
#  'Build a system any fool can use, and only a fool will want to use it.\n',
#  'Build something foolproof and every fool will use it.\n',
#  'Building a better mousetrap merely results in smarter mice.\n',
#  "Bumper sticker: My politics don't fit on a bumper sticker. â€” John Shelton\n",
#  'Bureaucracy: A giant mechanism operated by pygmies. â€” Honor de Balzac\n',
#  'Business first and pleasure afterwards. â€” Surtees\n',
#  'Business is a combination of war and sport. â€” Andre Maurois\n',
#  "Busy souls have no time to be busybodies. â€” Austin O'Malley\n",
#  'But "yes" can mean so many things. â€” John Taylor\n',
#  "But how can fame and profit concern a man of genius? â€” Li Ch'i\n",
#  'But in this world nothing is certain but death and taxes. â€” Benjamin Franklin\n',
#  'But it does move! â€” Galileo Galilei\n',
#  'Buy low, sell high.\n',
#  'By allowing her to be totally herself... She frees me to to be totally myself.\n',
#  'By failing to prepare, you are preparing to fail.\n',
#  'By nature, men are nearly alike; by practice, they get to be far apart.\n',
#  'By protracting life, we do not deduct one jot from the duration of death.\n',
#  'By the time everyone agrees, it is too late.\n',
#  "By the yard, life is hard. By the inch, it's a cinch.\n",
#  'By their fruit you will recognize them. (By their works ye shall know them.) â€” Matthew 7:16\n',
#  'Cabbage has a higher yield per acre than any other vegetable.\n',
#  'Call on God, but row away from the rocks. â€” Indian proverb\n',
#  'Calling religion a mental illness is really insulting to mentally ill people. â€” Cristina Rad\n',
#  'Can anyone remember when the times were not hard and money not scarce? â€” Ralph Emerson\n',
#  'Can anything be sadder than work left unfinished? Yes, work never begun.\n',
#  'Cancer cures smoking.\n',
#  'Capability does not imply intent.\n',
#  'Capitalism is the exploitation of one man by another; socialism is the reverse.\n',
#  'Capitalists will sell themselves the rope to hang themselves with.\n',
#  'Care is no cure. â€” Greene\n',
#  'Carrying resentment is like drinking poison and waiting for someone else to die.\n',
#  'Cast not out the foul water till you bring in the clean. â€” James Carmichaell\n',
#  'Cats, no less liquid than their shadows, offer no angles to the wind.\n',
#  "Celebrity isn't an achievement in itself. â€” Carol Loomis\n",
#  'Certain actors in history change the world by staging their own defeat. â€” Wolf\n',
#  'Chance favors the prepared mind. â€” Louis Pasteur\n',
#  'Chance is perhaps the pseudonym of God when He did not want to sign. â€” France\n',
#  'Change your mind as often as the facts change. â€” Morgan Housel\n',
#  'Change your thoughts and you change your world.\n',
#  'Character consists of what you do on the third and fourth tries. â€” Michener\n',
#  'Character is not made in a crisis â€” it is only exhibited. â€” Robert Freeman\n',
#  'Character is the power to change the face of things.\n',
#  'Character is what you are in the dark. â€” Dwight Moody\n',
#  'Charity begins at home.\n',
#  'Charity should be spontaneous. Calculated altruism is an affront. â€” Edward Abbey\n',
#  'Charm is the quality in others that makes us more satisfied with ourselves.\n',
#  'Chastity and virtue are their own punishment.\n',
#  'Chastity is more a state of mind than of anatomy. â€” Edward Abbey\n',
#  'Chastity is no more a virtue than malnutrition. â€” Alex Comfort\n',
#  'Cheap things are of no value, valuable things are not cheap.\n',
#  "Check again to ensure it's not loaded.\n",
#  "Children are poor men's riches.\n",
#  'Children become ready for toilet training and independence at the same time.\n',
#  'Children have more need of models than of critics.\n',
#  'Children need love, especially when they do not deserve it.\n',
#  'Choice is a terrifying power. â€” Carolyn Myss\n',
#  'Choice of words is spontaneous but no accident. â€” NLP\n',
#  'Choice within constraint is essential; choice without constraint is paralyzing. â€” Barry Schwartz\n',
#  'Choose happiness for yourself regardless of what others do.\n',
#  'Choose not a spouse by the eye only.\n',
# ...
#  'Consistency is the last refuge of the unimaginative. â€” Oscar Wilde\n',
#  'Consistency is the quality of a stagnant mind. â€” John Sloan\n',
#  'Consistency requires you to be as ignorant today as you were a year ago.\n',
#  'Constant reorganization is the hallmark of a dynamic organization.\n',
#  'Contentment is the smother of invention. â€” Laura Watson\n',
#  'Contexts serve as (mental) primers. â€” Ellen Langer\n',
#  'Conversation enriches the understanding, but solitude is the school of genius.\n',
#  'Convincing yourself that a bad idea is a good idea is a bad idea.\n',
#  'Cooler heads will prevail.\n',
#  'Cooperation: Doing with a smile what you are forced to do.\n',
#  'Corporations as persons, not property, let them deny the rights of real persons.\n',
#  'Correlation does not imply causation.\n',
#  'Counsel must be followed, not praised. â€” Lyly\n',
#  'Courage is grace under pressure.\n',
#  'Courage is not the absence of fear but the conquest of it. â€” Scott Cochran\n',
#  'Courage is the price life exacts for granting peace. â€” Amelia Earhart\n',
#  'Covetousness brings nothing home.\n',
#  'Cowards are cruel but the brave love mercy. â€” Gay\n',
#  'Cream rises to the top, but so does scum.\n',
#  'Creation is a mighty joke, but the laugh is at my own expense. â€” Meher Baba\n',
#  'Creativity is allowing oneself to make mistakes. Art is knowing which to keep.\n',
#  'Creativity is no substitute for knowing what you are doing.\n',
#  'Creativity, like love, should be diagnosed retrospectively. â€” John Schimel\n',
#  'Credible people sign their work.\n',
#  'Creditors have much better memories than debtors.\n',
#  'Crisis is a motivator for change.\n',
#  'Criticism comes easier than craftsmanship. â€” Zeuxis\n',
#  'Cult: A small, unpopular religion. Religion: A large, popular cult.\n',
#  'Cultivate happiness and it becomes a habit.\n',
#  'Culture is the habit of being pleased with the best and knowing why.\n',
#  "Curiosity is ill manners in another's house. â€” Oudin\n",
#  'Curiosity will conquer fear even more than bravery will. â€” James Stephens\n',
#  'Cynicism is an unpleasant way of saying the truth. â€” Lillian Hellman\n',
#  'Darkness is cheap. â€” Charles Dickens\n',
#  "Data isn't information; information isn't knowledge; knowledge isn't wisdom.\n",
#  'De gustibus non es disputandum. (In matters of taste there can be no disputes.) â€” old Roman axiom\n',
#  'Dead men tell no tales.\n',
#  'Deal with reality, or reality will deal with you.\n',
#  'Death and taxes may be inevitable, but they should not be simultaneous. â€” Mack\n',
#  "Death is a self-fulfilling prophecy. You just don't dwell on it. â€” Nance\n",
#  "Death is every man's final critic. To die well you must live bravely. â€” Edward Abbey\n",
#  "Death is just nature's way of telling you to slow down.\n",
#  'Death is the one experience that we cannot put in perspective afterwards.\n',
#  'Death is the ultimate low, from which we do not recover. â€” Kevin Keirn\n',
#  'Death keeps no calendar. â€” George Herbert\n',
#  'Death pays all debts.\n',
#  'Decisions terminate panic.\n',
#  'Deeds are fruits, words are but leaves. â€” Thomas Draxe\n',
#  'Deeds are males, and words are females. â€” Sanford\n',
#  'Defeat is worse than death because you have to live with defeat.\n',
#  'Degrees and credentials are primarily badges of compliance. â€” Bruce Levine\n',
#  'Delay is preferable to error. â€” Thomas Jefferson\n',
#  'Delay is the deadliest form of denial. â€” Parkinson\n',
#  'Delusion fends off disillusion. â€” Ben Staub\n',
#  'Democracy is good. I say this because other systems are worse. â€” Nehru\n',
#  'Democracy is the art of running the circus from the monkey cage. â€” Mencken\n',
#  'Democracy is the worst form of government â€” except for all the others.\n',
#  "Democracy is where you can say what you think even if you don't think.\n",
#  'Democracy means only that people are sovereign; not that they are infallible. â€” Rod Dreher\n',
#  'Dependable is not the same as accurate. â€” Frederick Brooks\n',
#  'Depression is anger without enthusiasm.\n',
#  "Deprive a mirror of its silver and even the Czar won't see his face.\n",
#  'Desire for greatness prevents its achievement.\n',
#  'Desire has no rest.\n',
#  'Desire unacted is corruption. â€” Ursula LeGuin\n',
#  'Desires and longings are the root cause of all suffering. â€” Meher Baba\n',
#  'Desires are nourished by delays.\n',
#  'Despair is the necessary prerequisite for the next level of consciousness.\n',
#  'Desperate diseases must have desperate cures.\n',
#  'Details call things into being. â€” Leonard Bernstein\n',
#  'Determine that the thing can and shall be done, and then we will find the way.\n',
#  "Devil's advocacy is an honorable profession.\n",
#  "Did God the designer choose a method designed precisely as if he wasn't there? â€” Richard Dawkins\n",
#  'Difficult to find a black cat in a dark room, especially if there is no cat. â€” Confucius\n',
#  'Discontent is the first step in the progress of a man or a nation. â€” Oscar Wilde\n',
#  'Discouragement is simply the despair of wounded self-love. â€” De Fenelon\n',
#  'Discussions of morality must inevitably lead to immoral statements. â€” Bradshaw\n',
#  'Disengage from consumerism as the main avenue of experience.\n',
#  'Dishonor will not trouble me, once I am dead.\n',
#  'Divine justice, and how it plays out, is perfect. â€” Carolyn Myss\n',
#  'Divorce can be a creative experience. â€” Will Limon\n',
#  'DNA is not really a thing, it is a memory. â€” Deepak Chopra\n',
#  'Do more than anyone expects, and pretty soon everyone will expect more.\n',
#  'Do not ask for what you will wish you had not got. â€” Seneca\n',
#  'Do not be angry with me if I tell you the truth. â€” Socrates\n',
#  'Do not be intimidated by reality.\n',
#  'Do not be overly suspicious where it is not warranted.\n',
#  'Do not beg trouble from the future. â€” Nancy Kirkwood\n',
#  'Do not believe everything you hear or anything you say.\n',
#  "Do not clog intellect's sluices with bits of knowledge of questionable uses.\n",
#  'Do not count your chickens before they are hatched. â€” Aesop\n',
#  'Do not cross a river if it is four feet deep on average. â€” Nassim Taleb\n',
#  'Do not handicap your children by making their lives easy. â€” Robert Heinlein\n',
#  'Do not judge a book by its cover.\n',
#  'Do not learn the tricks of the trade; learn the trade.\n',
#  'Do not seek answers that cannot be given; you would not be able to live them.\n',
#  "Do not stoop to tie your laces in your neighbor's melon patch.\n",
#  'Do not think by infection, catching an opinion like a cold.\n',
#  'Do not triumph before the victory.\n',
#  'Do not try to live forever. You will not succeed. â€” George Shaw\n',
#  'Do not worry about which side your bread is buttered on: You eat BOTH sides.\n',
#  'Do one thing every day that scares you. â€” Mary Schmich\n',
#  'Do the thing and have the power. â€” Ralph Emerson\n',
#  'Do to others as you would have them do unto you.\n',
#  'Do unto others as they would have you do unto them. â€” Haley\n',
#  'Do unto yourself as you would have others do unto you.\n',
#  'Do what you love, and follow your passion. â€” Jim and June Spencer\n',
#  'Do what you want â€” but KNOW what you are doing. â€” Kenny Washington\n',
#  'Do you ever just seem to not be able to get around to procrastinating?\n',
#  "Do you wish people to think well of you? Don't speak well of yourself. â€” Pascal\n",
#  'Doctors do not cry but men do. â€” Harry Weiss\n',
#  'Doctors think many patients are cured who have simply quit in disgust. â€” Herold\n',
#  'Does this path have a heart? â€” Carlos Castaneda\n',
#  'Dog wisdom: Avoid biting when a simple growl will do.\n',
#  'Dog wisdom: Eat with gusto and enthusiasm.\n',
#  'Dog wisdom: If what you want lies buried, dig until you find it.\n',
#  'Dog wisdom: Let others know when they have invaded your territory.\n',
#  'Dog wisdom: Take naps and stretch before rising.\n',
#  'Dog wisdom: Thrive on attention and let people touch you.\n',
#  'Dogma takes over when facts fail.\n',
#  'Dogs that bark at a distance bite not at hand. â€” Camden\n',
#  'Doing gets it done.\n',
#  'Doing is demonstrating that you know something.\n',
#  'Doing what you love is freedom. Loving what you do is happiness.\n',
#  "Doing your best is more important than being the best. â€” Cathy Rigby's mom\n",
#  "Dollar-cost average your entire life, you'll beat almost everyone who doesn't. â€” Morgan Housel\n",
#  "Don't be ashamed to say what you are not afraid to think. â€” Montaigne\n",
#  "Don't be mad about growing old. Some aren't that lucky.\n",
#  "Don't be reckless with other people's hearts. â€” Mary Schmich\n",
#  "Don't be so afraid of making a mistake that you can't make a decision.\n",
#  "Don't believe all you hear, spend all you have, or sleep all you want. â€” Brown\n",
#  "Don't burn any bridges you might need to cross again later.\n",
#  "Don't change a hair for me, not if you care for me. â€” Lee Coit\n",
#  "Don't compare your insides with other people's outsides.\n",
#  "Don't confuse mere inconveniences with real problems. â€” H. Jackson Brown\n",
#  "Don't confuse motion with progress (or effort with results).\n",
#  "Don't confuse things that need action with those that take care of themselves.\n",
#  "Don't congratulate yourself too much, or berate yourself either. â€” Mary Schmich\n",
#  "Don't count the days. Make the days count. â€” Muhammed Ali\n",
#  "Don't cross the bridge till you get to it. â€” Longfellow\n",
#  "Don't die until you're dead. â€” Billy Connolly\n",
#  "Don't do something. Just stand there. â€” Vanguard founder Jack Bogle\n",
#  "Don't ever slam a door; you might want to go back.\n",
#  "Don't expect drastic changes fast. Good practices require practice. â€” Hanson\n",
#  "Don't find fault, find a remedy; anyone can complain.\n",
#  "Don't get even â€” get better. â€” Carolyn Myss\n",
#  "Don't have good ideas if you aren't willing to be responsible for them.\n",
#  "Don't judge a man until you have walked a mile in his shoes. â€” Confucius\n",
#  "Don't judge your insides by other peoples' outsides.\n",
#  "Don't just adopt opinions; develop them.\n",
#  "Don't keep going to the well when the well is dry.\n",
#  "Don't kid yourself. Little is relevant, and nothing lasts forever.\n",
#  "Don't let editors edit the life out of your sentences! â€” Isaac Asimov\n",
#  "Don't let God laugh alone. â€” Josef Engressia\n",
#  "Don't let what you can't do stop you from doing what you can do.\n",
#  "Don't limit your challenges; challenge your limits. â€” Jerry Dunn\n",
#  "Don't look a gift horse in the mouth.\n",
#  "Don't look for the right person; be the right person. â€” Will Limon\n",
#  "Don't make a big deal out of everything; just deal with everything.\n",
#  "Don't make it a project. Much of the joy of things lies in their serendipity.\n",
#  "Don't meet troubles half-way. â€” Christer Sundqvist\n",
#  "Don't outlive your money. â€” H. Jackson Brown\n",
#  "Don't panic; calmness attracts answers.\n",
#  "Don't pet a dog you have just kicked.\n",
#  "Don't pick a fight with an old man. If too old to fight, he'll just kill you.\n",
#  "Don't put all of your eggs in one basket.\n",
#  "Don't put anything in writing that you wouldn't want to see in print. â€” Young\n",
#  "Don't run from love. There is no other direction.\n",
#  "Don't send your spirit on missions of destruction. â€” Carolyn Myss\n",
#  "Don't speak about Time, until you have spoken to him.\n",
#  "Don't stop along the way at all. That's illusion too. â€” Ram Dass\n",
#  "Don't stop to step on the ants when the elephants are stampeding.\n",
#  "Don't take anything seriously except happiness. â€” Albert Camus\n",
#  "Don't teach your children what to think; just teach them to think. â€” Tannenbaum\n",
#  "Don't tell me the sky's the limit when there are footprints on the moon. â€” Paul Brandt\n",
#  "Don't think that a house covered with snow has no fire in it. â€” George Shaw\n",
#  "Don't try to have the last word â€” you might get it. â€” Lazarus Long\n",
#  "Don't try to pitch from third base.\n",
#  "Don't use big words for little matters. â€” Samuel Johnson\n",
#  "Don't use yesterday as an excuse for not being fine. â€” Carolyn Myss\n",
#  "Don't use your powers, let them go. â€” Ram Dass\n",
#  "Don't Worry, Be Happy. â€” Meher Baba\n",
#  "Doubt is humble, and that's what man needs to be. â€” Bill Maher\n",
#  'Draw a circle around your love and hate will walk the line. â€” Hugh Prather\n',
#  'Draw your salary before spending it.\n',
#  'Drawing on my fine command of language, I said nothing. â€” Robert Benchley\n',
#  "Dream as if you'll live forever. Live as if you'll die tomorrow. â€” James Dean\n",
#  'Dry bread at home is better than roast meat abroad. â€” George Herbert\n',
#  'Dry socks are far more important than clean underwear. â€” Len McDougall\n',
#  'During depressions, assets return to their rightful owners. â€” Andrew Mellon\n',
#  'During the lows I find hope in knowing another high will come along. â€” Keirn\n',
#  'Duty is what one expects from others.\n',
#  'Each bird loves to hear himself sing. â€” Howell\n',
#  'Each circumstance is a gift, and in each experience is hidden a treasure. â€” God?\n',
#  "Each day can be whatever it is, and it's all right. â€” Ram Dass\n",
#  'Each man is his own prisoner, in solitary confinement for life.\n',
#  'Each of us bears his own Hell. â€” Publius Maro\n',
#  'Each one of us is an experiment-of-one. â€” George Sheehan\n',
#  'Each one of us is plugged into a schemata of archetypal patterns. â€” Carolyn Myss\n',
#  "Each person's journey into consciousness recapitulates all of man's journey.\n",
#  'Each problem solved introduces a new unsolved problem.\n',
#  'Early to bed and early to rise, makes a man healthy, wealthy, and wise.\n',
#  "Earth is the cradle of reason, but it's impossible to live eternally in cradles. â€” Konstantin Tsiolkovsky\n",
#  'Earth is the insane asylum of the universe.\n',
#  'Easy come, easy go.\n',
#  'Eat to live, and not live to eat. â€” Benjamin Franklin\n',
#  'Eat, drink, and be merry.\n',
#  'Eclipses clearly illuminate numerous features of society. â€” David Daye\n',
#  'Economic compulsion determines ethical perspective. â€” Lawrence Hirsch\n',
#  'Economy makes men independent.\n',
#  'Educated: Can hear almost anything without losing temper or self-confidence.\n',
#  'Education consists of pounding abstract ideas into concrete heads.\n',
#  'Education is a method whereby one acquires a higher grade of prejudice. â€” Peter\n',
#  'Education is a progressive discovery of our own ignorance. â€” Will Durant\n',
#  'Education is a weapon. â€” Josef Stalin\n',
#  'Education is the process of casting false pearls before real swine. â€” Edman\n',
#  'Education is what survives when what has been learnt has been forgotten.\n',
#  'Education makes a straight cut ditch of a free meandering brook. â€” Thoreau\n',
#  'Eighty percent of success is showing up. â€” Woody Allen\n',
#  'Eliminate any artificial "creativity" processes in the company. â€” Scott Adams\n',
#  'Emotion: Energy in motion.\n',
#  'Emotions honestly tell what is your investment and what are your expectations.\n',
#  'Empowering your child does not depower you. â€” Barbara Coloroso\n',
#  'Endurance is not toleration.\n',
#  'Energy flowing through a system organizes that system into greater complexity. â€” Alan MacRobert\n',
#  'Energy flows where attention goes. â€” Christiane Turner\n',
#  'Engineering is the art of knowing how to avoid difficult issues. â€” Dr. Budak\n',
#  'Engineering is the art of making the impossible possible. â€” Robert Zubrin\n',
#  'Engineers are the natural enemies of marketing people. â€” Scott Adams\n',
#  'Enjoy your body. Use it every way you can. â€” Mary Schmich\n',
#  "Enjoy yourself, it's later than you think. â€” Rasmus Petersen\n",
#  'Ensure your mind makes contracts your body can meet.\n',
#  'Envy and mediocrity are an explosive mixture. â€” Irvine Page\n',
#  'Envy is a pain of mind that successful men cause their neighbors.\n',
#  'Envy provides the mud that failure throws at success.\n',
#  'Established technology tends to persist in spite of new technology. â€” Blaauw\n',
#  ...]

# %%
quotes = []
for q in text:
    parts = q.split("â€")
    if len(parts) == 2:
        quotes.append(parts[0].strip())

# %%
quotes_clean = []
for q in quotes:
    if q[0] == '"':
        q = q[1:]
    if q[-1] == '"':
        q =q[:-1]
    quotes_clean.append(q)

# %%
len(quotes_clean)
# Out:
# 3055

# %%
quotes_clean
# Out:
# ['Do-so" is more important than "say-so".',
#  'For example" is not proof.',
#  "I really don't believe that, but I was raised that way.",
#  'Keep the tourists out..." As fellow tourists we heartily agree.',
#  'Know thyself"? If I knew myself, I\'d run away.',
#  '...context...',
#  "A baby is God's opinion that the world should go on.",
#  'A beggar can never be bankrupt.',
#  'A boss says, "Go!" A leader says, "Let\'s go!',
#  'A boy gets to be a man when a man is needed.',
#  "A business without a path to profit isn't a business, it's a hobby.",
#  'A city is a large community where people are lonesome together.',
#  'A civilized society makes swords into decoration.',
#  'A collection of facts not necessarily science.',
#  'A compliment is something like a kiss through a veil.',
#  'A confusion of the real with the ideal never goes unpunished.',
#  'A continuing flow of paper is sufficient to continue the flow of paper.',
#  "A critic is a man who knows the way but can't drive the car.",
#  'A critic is to an author as a fungus to an oak.',
#  'A culture can be no stronger than its strongest myths.',
#  'A day without fear changes your life forever.',
#  'A doctor gets no pleasure out of the health of his friends.',
#  'A dream that is not interpreted is like a letter that is not read.',
#  'A dying man can do nothing easy.',
#  'A feather in hand is better than a bird in the air.',
#  'A flood of words over a desert of thought.',
#  'A fool and his words are soon parted.',
#  'A foolish consistency is the hobgoblin of little minds.',
#  'A free society is one where it is safe to be unpopular.',
#  'A genius is always on duty; even his dreams are tax deductible.',
#  'A god can create a world only by listening.',
#  'A good example is the best sermon.',
#  'A good painter can draw a devil as well as an angel.',
#  'A good philosopher is one who does not take ideas seriously.',
#  'A good plan today is better than a perfect plan tomorrow.',
#  'A good tale cannot too often be told.',
#  'A good tongue is a good weapon.',
#  'A good word costs no more than a bad one.',
#  'A great ship asks deep waters.',
#  'A half-truth is closer to falsehood than to veracity.',
#  'A handful of sand is an anthology of the universe.',
#  'A hard life is a free lesson in poetry.',
#  'A hard-working farmer has plenty to eat.',
#  "A hen is only an egg's way of making another egg.",
#  'A hero is a man who does what he can.',
#  'A highbrow is a person educated beyond his intelligence.',
#  'A house is a large liability masquerading as a safe asset.',
#  'A house without books is like a room without windows.',
#  'A journey of a thousand miles must begin with a single step.',
#  'A learned fool is more foolish than an ignorant fool.',
#  'A leopard cannot change his spots.',
#  'A liar is not believed when he speaks the truth.',
#  'A liar needs a good memory.',
#  'A lie has a short life, but truth lives on for ever.',
#  'A life without tragedy would not be worth living.',
#  'A little fire consumes a great wood.',
#  'A little inaccuracy saves a world of explanation.',
#  'A little knowledge can be a ridiculous thing.',
#  'A little sunlight is the best disinfectant.',
#  'A living dog is better than a dead lion.',
#  'A long life deprives man of his optimism.',
#  'A long tongue is a sign of a short hand.',
#  'A man can do everything with a sword except sit on it.',
#  'A man can only be young once, but he can be immature forever.',
#  "A man doesn't become a failure until he is satisfied with being one.",
#  'A man is known to be mortal by two things, sleep and lust.',
#  'A man is not old until regrets take the place of dreams.',
#  'A man is not so soon healed as hurt.',
#  'A man may lose his goods for want of demanding them.',
#  'A man must not swallow more beliefs than he can digest.',
#  'A man never becomes an orator if he has anything to say.',
#  'A man who cannot seduce men cannot save them either.',
#  'A man who fears suffering is already suffering from what he fears.',
#  'A man will never change his mind if he has no mind to change.',
#  'A man without reason is a beast in season.',
#  "A man's envy alludes to where his ambition fails.",
#  "A man's library is his map drawn to scale.",
#  "A man's soul may be buried under a pile of money.",
#  'A mantra is a training device to break you out of your attachments.',
#  'A mask tells us more than the face.',
#  "A mathematician knows how to solve a problem, but can't do it.",
#  "A moment's insight is sometimes worth a life's experience.",
#  'A moneyless man goes fast through the market.',
#  'A museum is a collection of labels, illustrated by specimens.',
#  'A nerd is simply someone who thinks exceedingly inside the box.',
#  'A nuclear war cannot be won and must never be fought.',
#  'A pedestal is as much a prison as any small, confined space.',
#  'A penalty for hubris is always exacted.',
#  "A person before birth knows exactly what they're buying into.",
#  "A physicist is an atom's way of knowing about atoms.",
#  'A pious man is one who would be an atheist if the king were.',
#  "A plagiarist steals a writer's mental children.",
#  'A political career brings out the basest qualities in human nature.',
#  "A pragmatist is one who's ideology/theology has failed.",
#  'A prediction is but an explanation in advance.',
#  'A President is impeachable if he attempts to subvert the Constitution.',
#  'A problem is nothing more than a solution in disguise.',
#  'A professorship of theology should have no place in our institution.',
#  'A proliferation of theories is a symptom of a lack of data.',
#  'A prophet is not without honor save in his own country.',
#  'A prosperous fool is a grievous burden.',
#  'A proverb is a short sentence based on long experience.',
#  'A prudent question is one-half of wisdom.',
#  'A rising tide lifts all boats.',
#  'A rolling stone gathers no moss.',
#  'A scientist must be successful and not a success-fool.',
#  'A second fault ought not to be pardoned.',
#  'A sense of humor is just common sense, dancing.',
#  'A ship on the beach is a lighthouse to the sea.',
#  'A single death is a tragedy, a million deaths is a statistic.',
#  'A slave is one who waits for someone to come and free him.',
#  'A small fire makes often a great smoke.',
#  'A small leak will sink a great ship.',
#  'A smooth sea never made a skilled sailor.',
#  'A snowflake near lightspeed completely obliterates a planet, even Jupiter.',
#  'A straw vote only shows which way the hot air blows.',
#  'A stupid person cannot be advised.',
#  'A system meant for common use should rarely need uncommon knowledge.',
#  'A teacher affects eternity.',
#  'A thief passes for a gentleman when stealing has made him rich.',
#  'A thing is not true for you until it is true in thought, word, and deed.',
#  'A tree is known by its fruit.',
#  'A tribe is a group of people who honor the same perceptions.',
#  'A true leader cannot make anyone do something they do not want to do.',
#  "A truth that's told with bad intent beats all the lies you can invent.",
#  'A violent man will die a violent death.',
#  'A vision is only as good as the clarity of the image presented.',
#  'A wealth of information creates a poverty of attention.',
#  'A weed is a plant whose virtues have not been discovered.',
#  'A wise man cares not for what he cannot have.',
#  'A wise man is never surprised.',
#  'A witty saying proves nothing.',
#  'A woman is as old as she looks before breakfast.',
#  'A woman is as old as she looks to a man who likes to look at her.',
#  'A woman without a man is like a fish without a bicycle.',
#  'A word in time is worth two afterwards.',
#  'A word to the wise is enough.',
#  'A writer must not shift your point of view.',
#  'A yawn is a silent shout.',
#  'A young man might have more money than brains',
#  'A [person] without religion is like a fish without pajamas.',
#  'Ability has nothing to do with opportunity.',
#  'Absence makes the heart grow fonder.',
#  'Absence sharpens love. Presence strengthens it.',
#  'Absence works wonders.',
#  'Accept loneliness as normal, merely a sign that action is required.',
#  'Accept your ordination.',
#  'Achilles cannot defeat the tortoise if he thinks of space and time.',
#  'Action is what separates an opinion from a belief.',
#  'Actions speak louder than words.',
#  'Adaptation precludes adaptivity.',
#  "Addiction is an adaptation. It's not you. It's your cage.",
#  'Admit it, unplug, and get it over with.',
#  'Adversity makes a man wise, not rich.',
#  'Advice is a form of nostalgia.',
#  'Advice only works for the people that give it.',
#  'Affection blinds reason.',
#  'Affection makes a fool of any man.',
#  'After a calm comes a storm.',
#  'After age 30, we are all in extra innings.',
#  'After dinner sit awhile, after supper walk a mile.',
#  'After enlightenment, do the laundry.',
#  'After pleasure comes pain.',
#  'After the game, the king and the pawn go in the same box.',
#  'Age before beauty; and pearls before swine.',
#  'Age is like love, it cannot be hid.',
#  'All art is but imitation of nature.',
#  'All dreams are possible until proven otherwise.',
#  'All education is accompanied by pain.',
#  'All finite play is play against itself.',
#  'All forms of government are pernicious, including good government.',
#  'All generalizations are dangerous, even this one.',
#  "All gold is fool's gold.",
#  'All good work is done in defiance of management.',
#  'All governments need enemies. How else to justify their existence?',
#  'All great discoveries are made by mistake.',
#  'All great discoveries have been made from a willingness to not be right.',
#  'All great truths begin as blasphemies.',
#  'All hope abandon, ye who enter here!',
#  'All I know is, I will get guidance when I need it.',
#  'All I want from you is your joyful sharing.',
#  'All is not lost that is delayed.',
#  'All is well that ends well.',
#  'All laws are simulations of reality.',
#  'All life evolves by the differential survival of replicating entities.',
#  'All men are mortal.',
#  'All my life I wanted to be someone; I should have been more specific.',
#  'All philosophy lies in two words: Sustain and abstain.',
#  'All professions are organized conspiracies against the laity.',
#  'All progress depends on the unreasonable man.',
#  'All relationship is a mirror of your relationship with yourself.',
#  'All roads in the Middle East lead to the bizarre.',
#  'All roads lead to Rome.',
#  'All that we may see or seem, is but a dream within a dream.',
#  'All things are good untried.',
#  'All things merge into one, and a river runs through it.',
#  'All things obey money.',
#  'All wars are civil wars, because all men are brothers...',
#  'All we learn from history is that we learn nothing from history.',
#  'Allow each soul to walk its path.',
#  'Allow your children to face the consequences of their actions.',
#  "Almost everything looks better after a good night's sleep.",
#  'Almost was never hanged.',
#  'Alternatives exclude. Saying "yes" to one thing says "no" to another.',
#  'Always do what you are afraid to do.',
#  'Ambition is the last refuge of the failure.',
#  'Americans do the right thing, but only after exhausting all other possibilities.',
#  'An American is a man with two arms and four wheels.',
#  'An aphorism is a one-line novel.',
#  'An army is nothing but a well-organized lynch mob.',
#  'An army marches on its stomach.',
#  'An atheist is one point beyond the devil.',
#  'An easy answer to every human problem: Neat, plausible, and wrong.',
#  'An efficient bureaucracy is the greatest threat to liberty.',
#  'An egg today is better than a hen tomorrow.',
#  'An emotionless life is biologically impossible.',
#  'An empty man is full of himself.',
#  'An empty purse fills the face with wrinkles.',
#  'An empty stomach is not a good political advisor.',
#  'An era can be said to end when its basic illusions are exhausted.',
#  'An honest answer is a sign of true friendship.',
#  "An honest man's the noblest work of God.",
#  'An idea well-expressed is like a design of gold, set in silver.',
#  'An idealist is a person who helps other people to be prosperous.',
#  "An idle brain is the devil's shop.",
#  'An intellectual is someone whose mind watches itself.',
#  'An investment in knowledge always pays the best interest.',
#  'An occasion lost cannot be redeemed.',
#  'An ounce of application is worth a ton of abstraction.',
#  'An ounce of good fortune is worth a pound of forecast.',
#  'An owl is the king of the night.',
#  'Analogies prove nothing... But they can make one feel at home.',
#  "And malt does more than Milton can to justify God's ways to man.",
#  'And only the good die young.',
#  "And that's the way it is...",
#  'And tomorrow will be like today, only more so.',
#  'Angels do not support BS.',
#  'Anger goes after the first available target.',
#  'Anger is a short madness.',
#  'Animals cannot be harvested. They mature, but they do not ripen.',
#  'Another such victory over the Romans, and we are undone.',
#  'Answers almost never fulfill the promise of our questions.',
#  'Any clod can have the facts, but having opinions is an art.',
#  'Any difference that makes a difference is information.',
#  'Any difference that makes no difference is noise.',
#  "Any doom that can be predicted won't happen.",
#  'Any excuse will serve a tyrant.',
#  'Any fool can make a rule and every fool will mind it.',
#  'Any negativity can make you sick.',
#  'Any philosophy that can be put in a nutshell belongs there.',
#  'Any reality that you get stuck in is the wrong one.',
#  'Any sufficiently advanced technology is indistinguishable from magic.',
#  'Any technology distinguishable from magic is insufficiently advanced.',
#  'Anyone can hold the helm when the sea is calm.',
#  'Anyone can make history. Only a great man can write it.',
#  'Anyone can make mistakes, but only an idiot persists in his error.',
#  'Anyone may arrange his affairs so that his taxes shall be as low as possible.',
#  'Anyone without a sense of humor is at the mercy of everyone else.',
#  'Anything is easy if you can assimilate it to your collection of models.',
#  'Anything is possible, but only a few things actually happen.',
#  'Appearance VERSUS reality? Appearance IS reality...',
#  'Appearances often are deceiving.',
#  'Apply good consumerism to your love relationships.',
#  'Approach your limits from the safe side.',
#  'Architecture is frozen music.',
#  'Argue for your limitations and sure enough, they are yours.',
#  'Armed with these patterns, we go forward and brilliantly predict... the past.',
#  'Art has no enemy but ignorance.',
#  'Art is a lie that makes us realize the truth.',
#  'Art is never finished, only abandoned.',
#  'Artistic temperament is a disease that afflicts amateurs.',
#  'As a rule, pantheism is only a respectful variety of atheism.',
#  "As average skill increases, it's more difficult to outperform by large margins.",
#  "As far as the question of Martian life, if we don't go, we won't know.",
#  'As is the mother, so is her daughter.',
#  'As life is to live, so love is to give.',
#  'As others hurt and betray us, so are we the perpetrators of pain.',
#  'As silent as the grave.',
#  'As the area of your knowledge grows, so does the perimeter of your ignorance.',
#  'As the body becomes more limited, the soul expands.',
#  'As the question, so the answer.',
#  'As we migrated into Europe we discovered something new, called winter.',
#  'Ask a self-answering question; get a self-questioning answer.',
#  'Ask no questions and you will be told no lies.',
#  'Ask not for whom the bell tolls; it tolls for thee.',
#  "Ask not what's inside your head, but what your head's inside of.",
#  'Ask yourself whether you are happy and you cease to be so.',
#  'Assume the worst, hope for the best, accept reality.',
#  'Assumption is the mother of all screw-ups.',
#  'Astrology is true, but the astrologers cannot find it.',
#  'At 50, everyone has the face he deserves.',
#  'At either end of the social spectrum there lies a leisure class.',
#  'At retirement, human capital falls to zero.',
#  'Attachments fall away like a snake sheds its skin.',
#  'Attack the problem, not each other.',
#  'Avoid unnecessary dependency on large scale, harmful predictions.',
#  'Bad is never good until worse happens.',
#  "Be a good listener 'cause you never learn much from talking.",
#  'Be a light unto the darkness, and curse it not.',
#  'Be agreeable in manner, and resolute in action.',
#  "Be an expert on what's strong, not on what's wrong.",
#  'Be ashamed to die until you have won one victory for humanity.',
#  'Be bold in what you stand for and careful what you fall for.',
#  'Be both a speaker of words and a doer of deeds.',
#  'Be careful what you plug yourself into.',
#  'Be faithful to that which exists nowhere but in yourself.',
#  'Be fearful when others are greedy, and greedy when others are fearful.',
#  'Be good and you will be lonesome.',
#  'Be in the world but not of it.',
#  'Be kind and courteous to everyone.',
#  "Be nice to people on your way up; you'll meet them on your way down.",
#  'Be not anxious about what you have, but about what you are.',
#  'Be organized: This is a euphemism for being efficiently lazy.',
#  'Be sure your ladder of success is leaning against the right wall.',
#  'Be thou familiar, but by no means vulgar.',
#  'Beauty is one of the rare things which do not lead to doubt of God.',
#  'Beauty may have fair leaves, yet bitter fruit.',
#  "Beauty that doesn't make a woman vain makes her very beautiful.",
#  'Become famous for finishing important, difficult tasks.',
#  'Becoming number one is easier than remaining number one.',
#  'Before borrowing money from a friend, decide which you need more.',
#  'Before thirty, men seek disease; after thirty, diseases seek men.',
#  'Before you kill the cat, make arrangements for the mice.',
#  'Begin a lesson with a humorous illustration.',
#  'Being consistent is less important than being happy.',
#  'Being deserving of praise blinds us to flattery.',
#  'Being human involves becoming a burden.',
#  'Being lazy will make you poor, but hard work will make you rich.',
#  'Being on sea, sail; being on land, settle.',
#  'Being part of the tribal mind is part of your evolution.',
#  'Belief in God? An afterlife? I believe in rock...',
#  'Belief in the supernatural reflects a failure of the imagination.',
#  'Belief is not the beginning but the end of all knowledge.',
#  'Believe only half of what you see, and nothing that you hear.',
#  'Best is best cheap.',
#  'Better a cruel truth than a comfortable delusion.',
#  'Better a diamond with a flaw than a pebble without.',
#  'Better a lean peace than a fat victory.',
#  'Better a little loss than a long sorrow.',
#  'Better clean death than dirty life.',
#  'Better late than never.',
#  'Better some of a pudding than none of a pie.',
#  'Better the foot slip than the tongue.',
#  'Better to be ignorant of a matter than half know it.',
#  'Better to be patient on the road than a patient in the hospital.',
#  'Better to be poor and fear the Lord than to be rich and in trouble.',
#  'Better to be the head of an ass than the tail of a horse.',
#  'Better to reign in Hell then serve in Heaven.',
#  'Better untaught than ill taught.',
#  'Between a good reputation and great wealth, choose a good reputation.',
#  'Beware of all enterprises that require new clothes...',
#  'Beware of the man of one book.',
#  'Beware of the man who has no enemies.',
#  'Beware of your wishes: They will probably come true.',
#  'Beware temptation',
#  "Beware those who cannot tell God's will from their own.",
#  "Big brother isn't watching you, you're watching big brother",
#  "Bigger isn't always better, but better will always get bigger.",
#  'Biochemistry is the study of carbon compounds that crawl.',
#  'Blessed is he who expects nothing, for he shall never be disappointed.',
#  'Blessings on him that invented sleep!',
#  'Blinding speed can compensate for a lot of deficiencies.',
#  'Books as well as food nourish and warm people. Books make connections.',
#  'Boredom: The desire for desires.',
#  'Borrowed garments never fit well.',
#  "Bumper sticker: My politics don't fit on a bumper sticker.",
#  'Bureaucracy: A giant mechanism operated by pygmies.',
#  'Business first and pleasure afterwards.',
#  'Business is a combination of war and sport.',
#  'Busy souls have no time to be busybodies.',
#  'But "yes" can mean so many things.',
#  'But how can fame and profit concern a man of genius?',
#  'But in this world nothing is certain but death and taxes.',
#  'But it does move!',
#  'By their fruit you will recognize them. (By their works ye shall know them.)',
#  'Call on God, but row away from the rocks.',
#  'Calling religion a mental illness is really insulting to mentally ill people.',
#  'Can anyone remember when the times were not hard and money not scarce?',
#  'Care is no cure.',
#  'Cast not out the foul water till you bring in the clean.',
#  "Celebrity isn't an achievement in itself.",
#  'Certain actors in history change the world by staging their own defeat.',
#  'Chance favors the prepared mind.',
#  'Chance is perhaps the pseudonym of God when He did not want to sign.',
#  'Change your mind as often as the facts change.',
#  'Character consists of what you do on the third and fourth tries.',
#  'Character is what you are in the dark.',
#  'Charity should be spontaneous. Calculated altruism is an affront.',
#  'Chastity is more a state of mind than of anatomy.',
#  'Chastity is no more a virtue than malnutrition.',
#  'Choice is a terrifying power.',
#  'Choice of words is spontaneous but no accident.',
#  'Choice within constraint is essential; choice without constraint is paralyzing.',
#  'Christianity might be a good thing if anyone ever tried it.',
#  'Circumstances rule men; men do not rule circumstances.',
#  'Civility is a sign of strength, not weakness.',
#  'Civilization is limitless multiplication of unnecessary necessities.',
#  'Civilization is what the neutron bombs are supposed to leave intact.',
#  'Civilization remains a remote ideal.',
#  'Civilizations that make it in the long run must reintegrate into the biosphere.',
#  'Clarity is power.',
#  'Clear thinking requires courage rather than intelligence.',
#  'Cleverness is not wisdom.',
#  "Cloning is unnatural, but unnatural isn't... a synonym for bad.",
#  'Cogito ergo sum. (I think, therefore I am.)',
#  'Collective responsibility brings a lowering of moral standards.',
#  'College is a refuge from hasty judgment.',
#  'Comedy is tragedy plus time.',
#  'Comfort zones are most often expanded through discomfort.',
#  'Command yourself to feel good about yourself.',
#  'Common sense is instinct, and enough of it is genius.',
#  'Common sense is not so common.',
#  'Common sense, in an uncommon degree, is what the world calls wisdom.',
#  'Communication is next to impossible with someone who has no doubts.',
#  'Companionship is often shared loneliness.',
#  'Compensate complexity with simplicity.',
#  'Conceit causes more conversation than wit.',
#  'Conflict is inevitable but not necessarily bad.',
#  'Conflict is not possible without communication.',
#  'Conquer yourself instead of the world.',
#  "Conscience is God's presence in man.",
#  'Conscience makes egotists of us all.',
#  'Consciousness is a full-time job.',
#  'Consciousness is not an emergent property of the universe, but fundamental.',
#  'Consciousness means freedom from attachment.',
#  'Consistency is the last refuge of the unimaginative.',
#  'Consistency is the quality of a stagnant mind.',
#  'Contentment is the smother of invention.',
#  'Contexts serve as (mental) primers.',
#  'Counsel must be followed, not praised.',
#  'Courage is not the absence of fear but the conquest of it.',
#  'Courage is the price life exacts for granting peace.',
#  'Cowards are cruel but the brave love mercy.',
#  'Creation is a mighty joke, but the laugh is at my own expense.',
#  'Creativity, like love, should be diagnosed retrospectively.',
#  'Criticism comes easier than craftsmanship.',
#  "Curiosity is ill manners in another's house.",
#  'Curiosity will conquer fear even more than bravery will.',
#  'Cynicism is an unpleasant way of saying the truth.',
#  'Darkness is cheap.',
#  'De gustibus non es disputandum. (In matters of taste there can be no disputes.)',
#  'Death and taxes may be inevitable, but they should not be simultaneous.',
#  "Death is a self-fulfilling prophecy. You just don't dwell on it.",
#  "Death is every man's final critic. To die well you must live bravely.",
#  'Death is the ultimate low, from which we do not recover.',
#  'Death keeps no calendar.',
#  'Deeds are fruits, words are but leaves.',
#  'Deeds are males, and words are females.',
#  'Degrees and credentials are primarily badges of compliance.',
#  'Delay is preferable to error.',
#  'Delay is the deadliest form of denial.',
#  'Delusion fends off disillusion.',
#  'Democracy is good. I say this because other systems are worse.',
#  'Democracy is the art of running the circus from the monkey cage.',
#  'Democracy is the worst form of government',
#  'Democracy means only that people are sovereign; not that they are infallible.',
#  'Dependable is not the same as accurate.',
#  'Desire unacted is corruption.',
#  'Desires and longings are the root cause of all suffering.',
#  'Details call things into being.',
#  "Did God the designer choose a method designed precisely as if he wasn't there?",
#  'Difficult to find a black cat in a dark room, especially if there is no cat.',
#  'Discontent is the first step in the progress of a man or a nation.',
#  'Discouragement is simply the despair of wounded self-love.',
#  'Discussions of morality must inevitably lead to immoral statements.',
#  'Divine justice, and how it plays out, is perfect.',
#  'Divorce can be a creative experience.',
#  'DNA is not really a thing, it is a memory.',
#  'Do not ask for what you will wish you had not got.',
#  'Do not be angry with me if I tell you the truth.',
#  'Do not beg trouble from the future.',
#  'Do not count your chickens before they are hatched.',
#  'Do not cross a river if it is four feet deep on average.',
#  'Do not handicap your children by making their lives easy.',
#  'Do not try to live forever. You will not succeed.',
#  'Do one thing every day that scares you.',
#  'Do the thing and have the power.',
#  'Do unto others as they would have you do unto them.',
#  'Do what you love, and follow your passion.',
#  "Do you wish people to think well of you? Don't speak well of yourself.",
#  'Doctors do not cry but men do.',
#  'Doctors think many patients are cured who have simply quit in disgust.',
#  'Does this path have a heart?',
#  'Dogs that bark at a distance bite not at hand.',
#  'Doing your best is more important than being the best.',
#  "Dollar-cost average your entire life, you'll beat almost everyone who doesn't.",
#  "Don't be ashamed to say what you are not afraid to think.",
#  "Don't be reckless with other people's hearts.",
#  "Don't believe all you hear, spend all you have, or sleep all you want.",
#  "Don't change a hair for me, not if you care for me.",
#  "Don't confuse mere inconveniences with real problems.",
#  "Don't congratulate yourself too much, or berate yourself either.",
#  "Don't count the days. Make the days count.",
#  "Don't cross the bridge till you get to it.",
#  "Don't die until you're dead.",
#  "Don't do something. Just stand there.",
#  "Don't expect drastic changes fast. Good practices require practice.",
#  "Don't judge a man until you have walked a mile in his shoes.",
#  "Don't let editors edit the life out of your sentences!",
#  "Don't let God laugh alone.",
#  "Don't limit your challenges; challenge your limits.",
#  "Don't look for the right person; be the right person.",
#  "Don't meet troubles half-way.",
#  "Don't outlive your money.",
#  "Don't put anything in writing that you wouldn't want to see in print.",
#  "Don't send your spirit on missions of destruction.",
#  "Don't stop along the way at all. That's illusion too.",
#  "Don't take anything seriously except happiness.",
#  "Don't teach your children what to think; just teach them to think.",
#  "Don't tell me the sky's the limit when there are footprints on the moon.",
#  "Don't think that a house covered with snow has no fire in it.",
#  "Don't use big words for little matters.",
#  "Don't use yesterday as an excuse for not being fine.",
#  "Don't use your powers, let them go.",
#  "Don't Worry, Be Happy.",
#  "Doubt is humble, and that's what man needs to be.",
#  'Draw a circle around your love and hate will walk the line.',
#  'Drawing on my fine command of language, I said nothing.',
#  "Dream as if you'll live forever. Live as if you'll die tomorrow.",
#  'Dry bread at home is better than roast meat abroad.',
#  'Dry socks are far more important than clean underwear.',
#  'During depressions, assets return to their rightful owners.',
#  'During the lows I find hope in knowing another high will come along.',
#  'Each bird loves to hear himself sing.',
#  'Each circumstance is a gift, and in each experience is hidden a treasure.',
#  "Each day can be whatever it is, and it's all right.",
#  'Each of us bears his own Hell.',
#  'Each one of us is an experiment-of-one.',
#  'Each one of us is plugged into a schemata of archetypal patterns.',
#  "Earth is the cradle of reason, but it's impossible to live eternally in cradles.",
#  'Eat to live, and not live to eat.',
#  'Eclipses clearly illuminate numerous features of society.',
#  'Economic compulsion determines ethical perspective.',
#  'Education is a method whereby one acquires a higher grade of prejudice.',
#  'Education is a progressive discovery of our own ignorance.',
#  'Education is a weapon.',
#  'Education is the process of casting false pearls before real swine.',
#  'Education makes a straight cut ditch of a free meandering brook.',
#  'Eighty percent of success is showing up.',
#  'Eliminate any artificial "creativity" processes in the company.',
#  'Empowering your child does not depower you.',
#  'Energy flowing through a system organizes that system into greater complexity.',
#  'Energy flows where attention goes.',
#  'Engineering is the art of knowing how to avoid difficult issues.',
#  'Engineering is the art of making the impossible possible.',
#  'Engineers are the natural enemies of marketing people.',
#  'Enjoy your body. Use it every way you can.',
#  "Enjoy yourself, it's later than you think.",
#  'Envy and mediocrity are an explosive mixture.',
#  'Established technology tends to persist in spite of new technology.',
#  'Eternity is a mere moment, just long enough for a joke.',
#  'Eureka!',
#  "Even if we fail, we'll learn.",
#  "Even the best of friends cannot attend each other's funeral.",
#  'Every 5-7 years, people forget that recessions occur every 5-7 years.',
#  'Every blessing ignored becomes a curse.',
#  'Every cloud has a silver lining.',
#  'Every cubic inch in space is a miracle.',
#  'Every day you add one more day to your history.',
#  'Every exit is an entry somewhere else.',
#  'Every fool aspired to be a knave.',
#  'Every good idea started out as a bad idea.',
#  'Every human is... that profound secret and mystery to every other.',
#  'Every man dies... Not every man truly lives.',
#  'Every man has a right to be conceited until he is successful.',
#  'Every man has two vocations: His own and philosophy.',
#  'Every man is a fool sometimes, and none at all times.',
#  'Every man is all of man.',
#  'Every man is as God made him, ay, and often worse.',
#  'Every man is best known to himself.',
#  'Every man loves what he is good at.',
#  'Every man who takes office in Washington either grows or swells.',
#  'Every mile is two in winter.',
#  'Every minority group in order to survive works harder than usual.',
#  'Every moment is precious. And precarious.',
#  'Every nation has the government it deserves.',
#  'Every new generation is a fresh invasion of savages.',
#  'Every now and then, bite off more than you can chew.',
#  'Every pawn move loosens the position.',
#  'Every person on earth plays a central role in the history of the world.',
#  "Every revolution was first a thought in one man's mind.",
#  'Every saint has a past and every sinner has a future.',
#  'Every single person has his or her divine purpose for being here.',
#  'Every single person you relate to has a completely different culture.',
#  'Every truth starts life as a heresy and ends life as an orthodoxy.',
#  'Every truth that finally wakes up in you changes the rules of your life.',
#  'Every word is like an unnecessary stain on silence and nothingness.',
#  'Everybody has something to conceal.',
#  "Everybody is somebody else's weirdo.",
#  'Everyone does better when everyone does better.',
#  'Everyone in favor of birth control has already been born.',
#  'Everyone is entitled to his own opinion, but not his own facts.',
#  'Everyone is in the best seat.',
#  'Everyone is partly man and partly woman.',
#  'Everyone loves praise. Look hard for ways to give it to them.',
#  'Everyone you meet is fighting a battle you know nothing about.',
#  'Everyone, when they are young, knows what their destiny is.',
#  'Everything bows to success, even grammar.',
#  'Everything changes but change itself.',
#  'Everything has beauty, but not everyone sees it.',
#  'Everything has some value',
#  'Everything I did in my life that was worthwhile I caught hell for.',
#  'Everything in excess! To enjoy the flavor of life, take big bites.',
#  'Everything in the world may be endured except continual prosperity.',
#  'Everything in war is very simple, but the simplest thing is difficult.',
#  'Everything in your universe becomes your teacher.',
#  'Everything should be made as simple as possible, but not simpler.',
#  'Everything takes longer than you think it will.',
#  'Everything tends toward chaos.',
#  'Everything that used to be a sin is now a disease.',
#  'Evil is never intended as evil.',
#  'Evil is the termination of infinite play.',
#  'Evil is... the restriction of all play to one or another finite game.',
#  'Evolution is a theory that accounts for variety, not superiority.',
#  'Examine what is said, not him who speaks.',
#  'Example has more followers than reason.',
#  'Excellence is not an act but a habit.',
#  'Excellent things are hard to come by.',
#  'Exceptions are pernicious because they conceal laws.',
#  'Execute every act of thy life as though it were thy last.',
#  'Expectations are resentment in training.',
#  'Experience is sometimes dangerous.',
#  'Experience is the name everyone gives to their mistakes.',
#  'Experience keeps a dear school, but fools will learn in no other.',
#  'Expert advice is a great comfort, even when it is wrong.',
#  'Explanation is an antagonistic encounter.',
#  'Expressing anger is a form of public littering.',
#  'Extraordinary claims require extraordinary evidence.',
#  'Face reality: Consistently adequate is good enough.',
#  'Facts are meaningless except as part of a system.',
#  'Facts are stubborn things.',
#  'Facts do not cease to exist because they are ignored.',
#  'Fair words and foul play cheat both young and old.',
#  'Fair words make me look to my purse.',
#  'Faith means making a virtue out of not thinking.',
#  'Faith without works is dead.',
#  'Fake news has real consequences!',
#  'Fame is proof that people are gullible.',
#  'Fame is the perfume of heroic deeds.',
#  'Familiarity breeds contempt.',
#  'Fashion: A despot whom the wise ridicule and obey.',
#  'Fate knows best sometimes.',
#  'Fear is interest paid on a debt you may not owe.',
#  'Fear is the result of impurity.',
#  'Fear teaches us in the most graphic terms just what it is we value.',
#  'Feelings are neither good nor bad; they are just indicators.',
#  'Few of us seem to realize that pleasure is not the same as happiness.',
#  'Few people recover from having had a childhood.',
#  'Few, if any, survive their teens.',
#  'Fifty percent of something is better than 100 percent of nothing.',
#  "Figures won't lie, but liars will figure.",
#  'Financial diversification means always having to say you are sorry.',
#  'Find an aim in life before you run out of ammunition.',
#  'Finite play is inherently contradictory; infinite play is paradoxical.',
#  'Fire is a low-temperature phenomenon... in the universe.',
#  'First in time, first in right.',
#  'Flattery is like cologne: To be smelled, but not swallowed.',
#  'Float like a butterfly, sting like a bee.',
#  'Focused action beats brilliance any day.',
#  'Follow your bliss.',
#  'Folly grows without watering.',
#  'Food for thought is no substitute for the real thing.',
#  'Fool me once, shame on you. Fool me twice, shame on me.',
#  'Fools are always at the bottom of the food chain.',
#  "Fools don't attempt suicide; rather, they succeed at it.",
#  'For every credibility gap, there is a gullibility fill.',
#  "For God's sake, stop researching for a while and begin to think.",
#  'For humans, honest is a matter of degree.',
#  'For the love of money is the root of all evil.',
#  'For thee the wonder-working Earth puts forth sweet flowers.',
#  'For us there is only the trying.',
#  'Forbidden fruit is sweet.',
#  'Force has no place where there is need of skill.',
#  'Forget what you know and learn.',
#  'Forget your troubles as easily as you do your blessings.',
#  "Forgive us, for we also know not what we don't.",
#  'Forgive your enemies, but never forget their names.',
#  'Forgiveness is the attribute of the strong.',
#  'Freedom begins between the ears.',
#  'Freedom is its own punishment.',
#  'Freedom is nothing else but the chance to do better.',
#  'Freedom is slavery. Ignorance is strength. War is peace.',
#  'Freedom is the recognition of necessity.',
#  'Freedom is the right to be wrong, not the right to do wrong.',
#  'Freedom, not safety, is the highest good.',
#  'Friends may come and go, but enemies accumulate.',
#  'Friendship is one mind in two bodies.',
#  'From each according to his abilities, to each according to his needs.',
#  'From error to error, one discovers the entire truth.',
#  'From fanaticism to barbarism is only one step.',
#  'From hearing comes wisdom; from speaking, repentance.',
#  'Fruit ripens not well in the shade.',
#  'Furious activity is no substitute for understanding.',
#  'Genius is 1% inspiration and 99% perspiration.',
#  'Genius is born, not paid.',
#  'Genuine travel has no destination.',
#  'Geologic time is measured by mass extinctions.',
#  'Get up one time more than you are knocked down.',
#  'Getting old is giving up one damn thing after another.',
#  'Ghosts are the insomniacs among the dead.',
#  "Give me enough medals, and I'll win any war.",
#  'Give religion privilege, and it gets corrupted.',
#  "Given a choice between grief and nothing, I'd choose grief.",
#  'Glory is fleeting, but obscurity is forever.',
#  'Glory to the pattern finders. They make sense out of apparent chaos.',
#  "Goals... Plans... They're fantasies, part of a dream world...",
#  'God came to the United States in the form of LSD.',
#  'God complains not, but does what is fitting.',
#  'God does not play dice with the universe.',
#  'God gives us the nuts, but he does not crack them.',
#  'God heals and the doctor takes the fee.',
#  'God is great, too great for me.',
#  'God is not all-powerful as he cannot build a wall he cannot jump.',
#  'God is the tangential point between zero and infinity.',
#  'God made the integers; all else is the work of Man.',
#  "God may be subtle, but he isn't plain mean.",
#  'God offers to every mind its choice between truth and repose.',
#  'God sends meat and the devil sends cooks.',
#  'God strikes with his finger, and not with all his arm.',
#  'God walking on Earth is more important than man walking on the Moon.',
#  "God's career would end tomorrow were there no more problems.",
#  "God, it looks like it's going to be you and me for the rest of my life.",
#  "Gold that's put to use more gold begets.",
#  'Good artists borrow. Great artists steal.',
#  'Good behavior is the last refuge of mediocrity.',
#  'Good gift: Someone really wants it, but feels guilty buying it for themselves.',
#  "Good management is knowing what's fundamental to success and what's not.",
#  'Good memories have ill judgements.',
#  'Good men are scanty, make much of one.',
#  'Good poetry and bad poetry look pretty much the same at fifty yards.',
#  'Good teaching is one-fourth preparation and three-fourths theater.',
#  'Good words are worth much, and cost little.',
#  'Good, to forgive; best, to forget.',
#  'Gossip is so tasty, how we love to swallow it!',
#  'Grace is more beautiful than beauty.',
#  'Gratitude is a lively sense of future favors.',
#  'Gratitude is the memory of the heart.',
#  'Great achievements require relatively few ideas and even less men.',
#  'Great acts are made up of small deeds.',
#  "Great art is indefinable but that's all right; it exists anyway.",
#  'Great art is never perfect; perfect art is never great.',
#  'Great blunders are often made, like large ropes, of a multitude of fibers.',
#  'Great intellects are skeptical.',
#  'Great love and great achievements involve great risk.',
#  'Great men have great faults.',
#  'Great minds have purposes; others have wishes.',
#  'Greater qualities are necessary to bear good fortune than bad.',
#  'Grown men do not need leaders.',
#  'Growth for the sake of growth is the ideology of the cancer cell.',
#  'Half the truth is often a great lie.',
#  'Half the world knows not how the other half lives.',
#  'Happiness equals reality minus expectations.',
#  'Happiness is a perpetual possession of being well deceived.',
#  "Happiness isn't something you experience; it's something you remember.",
#  'Happy folks do not make history.',
#  'Happy is he that is happy in his children.',
#  'Happy is the man who becomes wise, who gains understanding.',
#  'Hard reality has a way of cramping your style.',
#  'Haste makes waste.',
#  'Hasten slowly.',
#  'Hate is a disease, and tolerance is the cure.',
#  'Hate stirs up trouble, but love overlooks all offenses.',
#  'Hate the sin and love the sinner.',
#  'Hating people is like burning down your own house to get rid of a rat.',
#  'Hatred is blind, as well as love.',
#  'Hatred is never ended by hatred but by love.',
#  'Have no friends not equal to yourself.',
#  'Have the courage to be honest with yourself.',
#  "Have you ever gone out to see how much fun you'd be to be with?",
#  'Having been poor is no shame, but being ashamed of it, is.',
#  'Having made one lie, he is fain to make more to maintain it.',
#  'Having nothing, nothing can he lose.',
#  'Having the fewest wants, I am nearest to the gods.',
#  'He bears misery best that hides it most.',
#  'He cannot be good that knows not why he is good.',
#  'He cries wine and sells vinegar.',
#  'He has not acquired a fortune; the fortune has acquired him.',
#  'He has slept well that remembers not he has slept ill.',
#  'He is a good orator who convinces himself.',
#  'He is now rising from affluence to poverty.',
#  'He is poor indeed that can promise nothing.',
#  'He is the best of men who dislikes power.',
#  'He jests at scars who never felt a wound.',
#  'He knows not how to know who knows not also how to unknow.',
#  'He knows not what good is who has not tried what evil is.',
#  'He laughs best that laughs last.',
#  'He loses his thanks who promises and delays.',
#  'He loses indeed that loses at last.',
#  'He loses nothing who keeps God for his friend.',
#  'He or she who would gather roses must not fear thorns.',
#  'He played the king as if afraid someone else would play the ace.',
#  'He sits not sure that sits too high.',
#  'He that bringeth a present, findeth the door open.',
#  'He that brings good news knocks hard.',
#  'He that cannot abide a bad market deserves not a good one.',
#  'He that cannot pay let him pray.',
#  'He that counts all costs will never put plow in the earth.',
#  'He that falls in love with himself, will have no rivals.',
#  'He that fears you present will hate you absent.',
#  'He that has a full purse never wanted a friend.',
#  'He that has no money needs no purse.',
#  'He that hurts another hurts himself.',
#  'He that is born a fool is never cured.',
#  'He that is carried down the stream need not row.',
#  'He that is fallen cannot help him that is down.',
#  'He that is giddy thinks the world turns round.',
#  'He that knows little soon repeats it.',
#  'He that knows nothing doubts nothing.',
#  'He that lends, gives.',
#  'He that lies upon the ground can fall no lower.',
#  'He that lives most, dies most.',
#  'He that lives well is learned enough.',
#  'He that lives wickedly can hardly die honestly.',
#  'He that loves well sees afar off.',
#  'He that makes a thing too fine, breaks it.',
#  'He that seeks finds.',
#  'He that sleeps with dogs must rise up with fleas.',
#  'He that speaks to a fool, talks to himself.',
#  'He that stays in the valley shall never get over the hill.',
#  'He that steals honey should beware of the sting.',
#  'He that will be served, must be patient.',
#  'He that will enter into Paradise must have a good key.',
#  'He was meant for a gentleman, but was spoilt in the making.',
#  'He who angers you, conquers you.',
#  'He who can, does. He who cannot, teaches.',
#  'He who defines the terms wins the argument.',
#  'He who fears the unknown may one day flee from his own backside.',
#  'He who fights and runs away lives to fight another day.',
#  'He who gives promptly gives twice.',
#  'He who has a WHY to live for can bear with almost any HOW.',
#  'He who hesitates is lost.',
#  'He who hesitates is sometimes saved.',
#  'He who knows others is wise. He who knows himself is enlightened.',
#  'He who knows that enough is enough will always have enough.',
#  'He who knows, does not speak. He who speaks, does not know.',
#  'He who opens a school door, closes a prison.',
#  'He who owes is in all wrong.',
#  'He who sees much can endure much.',
#  'He who slings mud generally loses ground.',
#  'He who wonders discovers that this in itself is wonder.',
#  'He who would climb the ladder must begin at the bottom.',
#  "He's poor as Job, and not so patient.",
#  'Health follows a change in mindset, just as in the case for placebos.',
#  'Hearts may agree, though heads differ.',
#  'Heaven does not worth according to human justice.',
#  'Heaven has no regard for physical comfort.',
#  'Heaven is to be at peace with all things.',
#  'Heaven is under our feet as well as over our heads.',
#  'Hell is always open.',
#  'Hell is wherever heaven is not.',
#  'Her head looks as if it had worn out two bodies.',
#  'Here it is standing: Atoms with consciousness; matter with curiosity.',
#  'Here lies a good fellow who spent his life while he had it.',
#  'Hey, everything goes wrong every minute. What you do is fix it.',
#  'Higher technology does not necessarily equate to higher anything else.',
#  'Historians are gossips who tease the dead.',
#  'History develops, art stands still.',
#  'History is any succession of events seen with the effect of posteriority.',
#  'History is not a spectator sport.',
#  'History is written by the survivors.',
#  'History knows no resting places and no plateaus.',
#  'History may not repeat but sometimes it rhymes.',
#  'History will be kind to me for I intend to write it.',
#  'Home is home, though it be never so homely.',
#  'Home is the sailor, home from the sea...',
#  "Home is where I want to be, but I guess I'm already there.",
#  'Honor lies in honest toil.',
#  'Hope is not a great investment strategy.',
#  "Hope is the poor man's bread.",
#  'Hope keeps man alive.',
#  'Hot love is soon cold.',
#  'Hot tempers cause arguments, but patience brings peace.',
#  'Houston, Tranquillity Base here. The Eagle has landed.',
#  "How are you going to shape the future if you don't know the past?",
#  'How beautiful it is to do nothing, and then rest afterward.',
#  'How can I know what I think until I see what I say?',
#  'How can so many take The Amazing Journey and not be amazed?',
#  'How do we acquire wisdom along with all these shiny things?',
#  'How does a project get to be a year late? One day at a time.',
#  'How long does it take to learn that violence begets violence?',
#  'Human beings live longer and better when they enjoy what they do.',
#  "Human rationality isn't a scientist, it's a lawyer.",
#  'Humans are captivated by stories, but largely oblivious to data.',
#  "Humans are communications junkies. We just can't get enough.",
#  'Humans are motivated by what has been done for them lately.',
#  "Humans can't think randomly.",
#  'Humans need simple answers for complex problems.',
#  'Humble hearts have humble desires.',
#  'Humility is a virtue when you have no other.',
#  'Humility to genius is as an extinguisher to a candle.',
#  "Humor is a drug which it's the fashion to abuse.",
#  'Humor is by far the most significant activity of the human brain.',
#  'Hunger is not caused by scarcity of food but scarcity of democracy.',
#  'Hunger is the best sauce.',
#  'Hunger knows no friend.',
#  'Hurt people hurt people.',
#  'Hypocrites are real atheists.',
#  'I am a deeply religious non-believer. This is a somewhat new kind of religion.',
#  "I am an enemy of the State. But isn't everyone?",
#  'I am becoming more energy than matter.',
#  'I am convinced the desire to formulate truths is a virulent disease.',
#  'I am cured of my illness; I am healed with my illness.',
#  'I am exactly where I am supposed to be.',
#  'I am glad I will not be young in a future without wilderness.',
#  'I am looking for an honest man.',
#  'I am not this thought.',
#  'I am the story I tell myself.',
#  'I am two fools, I know, for loving, and for saying so.',
#  'I believe in getting into hot water; it keeps you clean.',
#  'I believe in nothing that I cannot touch, kiss, embrace...',
#  'I can believe anything, provided it is incredible.',
#  "I can't afford to waste my time making money.",
#  "I can't complain, but sometimes I still do.",
#  "I cannot and will not cut my conscience to fit this year's fashions.",
#  "I cannot be alone; it's not possible.",
#  'I cannot prove this statement is true.',
#  'I cannot tell you my truth until you stop telling me yours.',
#  "I couldn't possibly fail to disagree with you less.",
#  'I do not believe in personal immortality; it seems so unnecessary.',
#  'I do not know myself and God forbid that I should.',
#  "I don't gamble. There are other ways to win at life.",
#  "I don't know, I don't care, and it doesn't make any difference.",
#  "I don't make the rules, Gil, I only play the game.",
#  "I don't see why any system of beliefs deserves respect simply because it exists.",
#  "I don't think comedy is an escape from tragedy. They are both life.",
#  "I don't want to make money. I just want to be wonderful.",
#  'I dream things that never were; and I say "Why not?',
#  'I fear explanations explanatory of things explained.',
#  'I find great humor in the fact that we ever take ourselves seriously.',
#  'I forgive and quite forget old faults.',
#  'I found Rome a city of bricks and left it a city of marble.',
#  'I have been a lucky man. But someone has to be.',
#  'I have lost all and found myself.',
#  'I have met my hero, and he is me.',
#  "I have never been hurt by anything I didn't say.",
#  'I have never let my schooling interfere with my education.',
#  'I have never, ever seen God come through the front door.',
#  'I have no special talents. I am only passionately curious.',
#  'I have nothing to say, and I am saying it.',
#  'I have often regretted my speech, never my silence.',
#  'I have promises to keep, and miles to go before I sleep.',
#  'I have with me two gods, Persuasion and Compulsion.',
#  'I know what I know, but I will keep it to myself.',
#  'I like being single. I am always there when I need me.',
#  "I might make you feel, but I can't make you think.",
#  'I never know how much of what I say is true.',
#  'I never think of the future. It comes soon enough.',
#  'I never tried quitting, and I never quit trying.',
#  "I never wish for anyone's death, but read a few obituaries with a chuckle.",
#  'I only know what I read in the papers.',
#  'I prefer rogues to imbeciles, because they sometimes take a rest.',
#  'I put up my thumb... And it blotted out the planet Earth.',
#  'I realized something about perfection... It comes only with time.',
#  'I respect faith, but doubt is what gets you an education.',
#  'I saw that, finally, my responsibility was to work on myself.',
#  'I say little but think the more.',
#  'I seem to be a verb.',
#  'I strive to be brief but I become obscure.',
#  'I think time is a merciless thing.',
#  'I touch the future. I teach.',
#  'I tremble for my country when I reflect that God is just.',
#  'I try not to break the rules but merely to test their elasticity.',
#  "I understand why you are confused. You're thinking too much.",
#  'I used to be disgusted, now I find I am just amused.',
#  'I wanted to do it just as he did; so I began to learn.',
#  'I wasted time and now doth time waste me.',
#  'I will do nothing for you that you will not do for your Self.',
#  "I wish I didn't know now what I didn't know then.",
#  'I would consider it an honor to be fossilized.',
#  'I would like to know what I was fencing in and what I was fencing out.',
#  'I would rather be the first man here than the second in Rome.',
#  'I [am] a channel through which music emerges from the chaos of noise.',
#  "I'd much rather see lube oil running out of a bearing than metal particles.",
#  "I'll meet you... on the dark side... of the moon...",
#  "I'm against a homogenized society because I want the cream to rise.",
#  "I'm always doing that which I cannot do, in order that I may learn how to do it.",
#  "I'm an idealist. I don't know where I'm going, but I'm on my way!",
#  "I'm running out of cheeks to turn.",
#  "I've finally become what I had merely intended to seem.",
#  "If a camel flies, no one laughs if it doesn't get very far.",
#  'If a cat has nine lives, a lie has ninety-nine.',
#  'If a document is over two pages long, few people will ever read it.',
#  'If a fool persists in his folly he shall become wise.',
#  "If a guy is over 25% jerk, he's in trouble.",
#  'If a man has talent and cannot use it, he has failed.',
#  'If a man hears much that a woman says, she is not beautiful.',
#  "If a person can't communicate, the very least he can do is to shut up!",
#  'If a plant grows in abundance, it is a plant of virtue.',
#  'If a string has one end, then it has another end.',
#  "If a thing's worth doing, it is worth doing badly.",
#  'If anything can go wrong, it will.',
#  'If anything is sacred, the human body is sacred.',
#  "If at first you don't succeed, try, try again.",
#  'If Christ were here now there is one thing he would not be',
#  'If everybody was satisfied with himself, there would be no heroes.',
#  'If God did not exist, it would be necessary to invent him.',
#  'If guns are outlawed, only the government will have guns.',
#  'If happiness is in your destiny, you need not be in a hurry.',
#  'If he works for you, you work for him.',
#  'If I cannot bend Heaven, I shall move Hell.',
#  ...]

# %%
html_clean = " ".join(html.split("\n"))
paragraphs = re.findall(r'<p>(.*?)</p>', html_clean)
corpus = []
for p in paragraphs:
    if "—" not in p:
        quote = "'".join(p.split("&rsquo;"))
        corpus.append(quote)

# %%
with urllib.request.urlopen('https://www.gutenberg.org/files/11/11-h/11-h.htm') as f:
    htm = f.read().decode('utf-8')
htm_clean = " ".join(htm.split("\n"))
paragraphs = re.findall(r'<p>(.*?)</p>', htm_clean)

# %%
pars = []
for p in paragraphs:
    pars.append(html.unescape(p.replace("\r","").strip()))
text = " ".join(pars)

# %%
text = text.replace("<i>","")
text = text.replace("</i>", "")

# %%
nlp = spacy.load("en_core_web_sm")

# %%
from spacy.pipeline import Sentencizer

senticer = Sentencizer(punct_chars=["."])
nlp.add_pipe(senticer, before = "parser")

doc = nlp(text)

# %%
def set_custom_boundaries(doc):
    for i, token in enumerate(doc):
          
        if token.text in ("!"):
            doc[i].is_sent_end = False
            
        if token.text in ("’s", "'s"):
            doc[i].is_sent_start = False
        elif token.text in ("“", "‘") and i < len(doc) - 1:
            # opening quote
            doc[i+1].is_sent_start = False
        elif token.text in ("”", "’"):
            # closing quote
            doc[i].is_sent_start = False
    return doc

# %%
corpus = [s.text.strip() for s in doc.sents]

# %%
corpus = quotes_clean

# %%
with open("corpus.txt", "w") as f:
    for p in corpus:
        f.writelines(p + "\n")

# %%
with open("corpus.txt", "r") as f:
        corpus= [s.strip() for s in f.readlines()]

# %%
corpus
# Out:
# ['Do-so" is more important than "say-so".',
#  'For example" is not proof.',
#  "I really don't believe that, but I was raised that way.",
#  'Keep the tourists out..." As fellow tourists we heartily agree.',
#  'Know thyself"? If I knew myself, I\'d run away.',
#  '...context...',
#  "A baby is God's opinion that the world should go on.",
#  'A beggar can never be bankrupt.',
#  'A boss says, "Go!" A leader says, "Let\'s go!',
#  'A boy gets to be a man when a man is needed.',
#  "A business without a path to profit isn't a business, it's a hobby.",
#  'A city is a large community where people are lonesome together.',
#  'A civilized society makes swords into decoration.',
#  'A collection of facts not necessarily science.',
#  'A compliment is something like a kiss through a veil.',
#  'A confusion of the real with the ideal never goes unpunished.',
#  'A continuing flow of paper is sufficient to continue the flow of paper.',
#  "A critic is a man who knows the way but can't drive the car.",
#  'A critic is to an author as a fungus to an oak.',
#  'A culture can be no stronger than its strongest myths.',
#  'A day without fear changes your life forever.',
#  'A doctor gets no pleasure out of the health of his friends.',
#  'A dream that is not interpreted is like a letter that is not read.',
#  'A dying man can do nothing easy.',
#  'A feather in hand is better than a bird in the air.',
#  'A flood of words over a desert of thought.',
#  'A fool and his words are soon parted.',
#  'A foolish consistency is the hobgoblin of little minds.',
#  'A free society is one where it is safe to be unpopular.',
#  'A genius is always on duty; even his dreams are tax deductible.',
#  'A god can create a world only by listening.',
#  'A good example is the best sermon.',
#  'A good painter can draw a devil as well as an angel.',
#  'A good philosopher is one who does not take ideas seriously.',
#  'A good plan today is better than a perfect plan tomorrow.',
#  'A good tale cannot too often be told.',
#  'A good tongue is a good weapon.',
#  'A good word costs no more than a bad one.',
#  'A great ship asks deep waters.',
#  'A half-truth is closer to falsehood than to veracity.',
#  'A handful of sand is an anthology of the universe.',
#  'A hard life is a free lesson in poetry.',
#  'A hard-working farmer has plenty to eat.',
#  "A hen is only an egg's way of making another egg.",
#  'A hero is a man who does what he can.',
#  'A highbrow is a person educated beyond his intelligence.',
#  'A house is a large liability masquerading as a safe asset.',
#  'A house without books is like a room without windows.',
#  'A journey of a thousand miles must begin with a single step.',
#  'A learned fool is more foolish than an ignorant fool.',
#  'A leopard cannot change his spots.',
#  'A liar is not believed when he speaks the truth.',
#  'A liar needs a good memory.',
#  'A lie has a short life, but truth lives on for ever.',
#  'A life without tragedy would not be worth living.',
#  'A little fire consumes a great wood.',
#  'A little inaccuracy saves a world of explanation.',
#  'A little knowledge can be a ridiculous thing.',
#  'A little sunlight is the best disinfectant.',
#  'A living dog is better than a dead lion.',
#  'A long life deprives man of his optimism.',
#  'A long tongue is a sign of a short hand.',
#  'A man can do everything with a sword except sit on it.',
#  'A man can only be young once, but he can be immature forever.',
#  "A man doesn't become a failure until he is satisfied with being one.",
#  'A man is known to be mortal by two things, sleep and lust.',
#  'A man is not old until regrets take the place of dreams.',
#  'A man is not so soon healed as hurt.',
#  'A man may lose his goods for want of demanding them.',
#  'A man must not swallow more beliefs than he can digest.',
#  'A man never becomes an orator if he has anything to say.',
#  'A man who cannot seduce men cannot save them either.',
#  'A man who fears suffering is already suffering from what he fears.',
#  'A man will never change his mind if he has no mind to change.',
#  'A man without reason is a beast in season.',
#  "A man's envy alludes to where his ambition fails.",
#  "A man's library is his map drawn to scale.",
#  "A man's soul may be buried under a pile of money.",
#  'A mantra is a training device to break you out of your attachments.',
#  'A mask tells us more than the face.',
#  "A mathematician knows how to solve a problem, but can't do it.",
#  "A moment's insight is sometimes worth a life's experience.",
#  'A moneyless man goes fast through the market.',
#  'A museum is a collection of labels, illustrated by specimens.',
#  'A nerd is simply someone who thinks exceedingly inside the box.',
#  'A nuclear war cannot be won and must never be fought.',
#  'A pedestal is as much a prison as any small, confined space.',
#  'A penalty for hubris is always exacted.',
#  "A person before birth knows exactly what they're buying into.",
#  "A physicist is an atom's way of knowing about atoms.",
#  'A pious man is one who would be an atheist if the king were.',
#  "A plagiarist steals a writer's mental children.",
#  'A political career brings out the basest qualities in human nature.',
#  "A pragmatist is one who's ideology/theology has failed.",
#  'A prediction is but an explanation in advance.',
#  'A President is impeachable if he attempts to subvert the Constitution.',
#  'A problem is nothing more than a solution in disguise.',
#  'A professorship of theology should have no place in our institution.',
#  'A proliferation of theories is a symptom of a lack of data.',
#  'A prophet is not without honor save in his own country.',
#  'A prosperous fool is a grievous burden.',
#  'A proverb is a short sentence based on long experience.',
#  'A prudent question is one-half of wisdom.',
#  'A rising tide lifts all boats.',
#  'A rolling stone gathers no moss.',
#  'A scientist must be successful and not a success-fool.',
#  'A second fault ought not to be pardoned.',
#  'A sense of humor is just common sense, dancing.',
#  'A ship on the beach is a lighthouse to the sea.',
#  'A single death is a tragedy, a million deaths is a statistic.',
#  'A slave is one who waits for someone to come and free him.',
#  'A small fire makes often a great smoke.',
#  'A small leak will sink a great ship.',
#  'A smooth sea never made a skilled sailor.',
#  'A snowflake near lightspeed completely obliterates a planet, even Jupiter.',
#  'A straw vote only shows which way the hot air blows.',
#  'A stupid person cannot be advised.',
#  'A system meant for common use should rarely need uncommon knowledge.',
#  'A teacher affects eternity.',
#  'A thief passes for a gentleman when stealing has made him rich.',
#  'A thing is not true for you until it is true in thought, word, and deed.',
#  'A tree is known by its fruit.',
#  'A tribe is a group of people who honor the same perceptions.',
#  'A true leader cannot make anyone do something they do not want to do.',
#  "A truth that's told with bad intent beats all the lies you can invent.",
#  'A violent man will die a violent death.',
#  'A vision is only as good as the clarity of the image presented.',
#  'A wealth of information creates a poverty of attention.',
#  'A weed is a plant whose virtues have not been discovered.',
#  'A wise man cares not for what he cannot have.',
#  'A wise man is never surprised.',
#  'A witty saying proves nothing.',
#  'A woman is as old as she looks before breakfast.',
#  'A woman is as old as she looks to a man who likes to look at her.',
#  'A woman without a man is like a fish without a bicycle.',
#  'A word in time is worth two afterwards.',
#  'A word to the wise is enough.',
#  'A writer must not shift your point of view.',
#  'A yawn is a silent shout.',
#  'A young man might have more money than brains',
#  'A [person] without religion is like a fish without pajamas.',
#  'Ability has nothing to do with opportunity.',
#  'Absence makes the heart grow fonder.',
#  'Absence sharpens love. Presence strengthens it.',
#  'Absence works wonders.',
#  'Accept loneliness as normal, merely a sign that action is required.',
#  'Accept your ordination.',
#  'Achilles cannot defeat the tortoise if he thinks of space and time.',
#  'Action is what separates an opinion from a belief.',
#  'Actions speak louder than words.',
#  'Adaptation precludes adaptivity.',
#  "Addiction is an adaptation. It's not you. It's your cage.",
#  'Admit it, unplug, and get it over with.',
#  'Adversity makes a man wise, not rich.',
#  'Advice is a form of nostalgia.',
#  'Advice only works for the people that give it.',
#  'Affection blinds reason.',
#  'Affection makes a fool of any man.',
#  'After a calm comes a storm.',
#  'After age 30, we are all in extra innings.',
#  'After dinner sit awhile, after supper walk a mile.',
#  'After enlightenment, do the laundry.',
#  'After pleasure comes pain.',
#  'After the game, the king and the pawn go in the same box.',
#  'Age before beauty; and pearls before swine.',
#  'Age is like love, it cannot be hid.',
#  'All art is but imitation of nature.',
#  'All dreams are possible until proven otherwise.',
#  'All education is accompanied by pain.',
#  'All finite play is play against itself.',
#  'All forms of government are pernicious, including good government.',
#  'All generalizations are dangerous, even this one.',
#  "All gold is fool's gold.",
#  'All good work is done in defiance of management.',
#  'All governments need enemies. How else to justify their existence?',
#  'All great discoveries are made by mistake.',
#  'All great discoveries have been made from a willingness to not be right.',
#  'All great truths begin as blasphemies.',
#  'All hope abandon, ye who enter here!',
#  'All I know is, I will get guidance when I need it.',
#  'All I want from you is your joyful sharing.',
#  'All is not lost that is delayed.',
#  'All is well that ends well.',
#  'All laws are simulations of reality.',
#  'All life evolves by the differential survival of replicating entities.',
#  'All men are mortal.',
#  'All my life I wanted to be someone; I should have been more specific.',
#  'All philosophy lies in two words: Sustain and abstain.',
#  'All professions are organized conspiracies against the laity.',
#  'All progress depends on the unreasonable man.',
#  'All relationship is a mirror of your relationship with yourself.',
#  'All roads in the Middle East lead to the bizarre.',
#  'All roads lead to Rome.',
#  'All that we may see or seem, is but a dream within a dream.',
#  'All things are good untried.',
#  'All things merge into one, and a river runs through it.',
#  'All things obey money.',
#  'All wars are civil wars, because all men are brothers...',
#  'All we learn from history is that we learn nothing from history.',
#  'Allow each soul to walk its path.',
#  'Allow your children to face the consequences of their actions.',
#  "Almost everything looks better after a good night's sleep.",
#  'Almost was never hanged.',
#  'Alternatives exclude. Saying "yes" to one thing says "no" to another.',
#  'Always do what you are afraid to do.',
#  'Ambition is the last refuge of the failure.',
#  'Americans do the right thing, but only after exhausting all other possibilities.',
#  'An American is a man with two arms and four wheels.',
#  'An aphorism is a one-line novel.',
#  'An army is nothing but a well-organized lynch mob.',
#  'An army marches on its stomach.',
#  'An atheist is one point beyond the devil.',
#  'An easy answer to every human problem: Neat, plausible, and wrong.',
#  'An efficient bureaucracy is the greatest threat to liberty.',
#  'An egg today is better than a hen tomorrow.',
#  'An emotionless life is biologically impossible.',
#  'An empty man is full of himself.',
#  'An empty purse fills the face with wrinkles.',
#  'An empty stomach is not a good political advisor.',
#  'An era can be said to end when its basic illusions are exhausted.',
#  'An honest answer is a sign of true friendship.',
#  "An honest man's the noblest work of God.",
#  'An idea well-expressed is like a design of gold, set in silver.',
#  'An idealist is a person who helps other people to be prosperous.',
#  "An idle brain is the devil's shop.",
#  'An intellectual is someone whose mind watches itself.',
#  'An investment in knowledge always pays the best interest.',
#  'An occasion lost cannot be redeemed.',
#  'An ounce of application is worth a ton of abstraction.',
#  'An ounce of good fortune is worth a pound of forecast.',
#  'An owl is the king of the night.',
#  'Analogies prove nothing... But they can make one feel at home.',
#  "And malt does more than Milton can to justify God's ways to man.",
#  'And only the good die young.',
#  "And that's the way it is...",
#  'And tomorrow will be like today, only more so.',
#  'Angels do not support BS.',
#  'Anger goes after the first available target.',
#  'Anger is a short madness.',
#  'Animals cannot be harvested. They mature, but they do not ripen.',
#  'Another such victory over the Romans, and we are undone.',
#  'Answers almost never fulfill the promise of our questions.',
#  'Any clod can have the facts, but having opinions is an art.',
#  'Any difference that makes a difference is information.',
#  'Any difference that makes no difference is noise.',
#  "Any doom that can be predicted won't happen.",
#  'Any excuse will serve a tyrant.',
#  'Any fool can make a rule and every fool will mind it.',
#  'Any negativity can make you sick.',
#  'Any philosophy that can be put in a nutshell belongs there.',
#  'Any reality that you get stuck in is the wrong one.',
#  'Any sufficiently advanced technology is indistinguishable from magic.',
#  'Any technology distinguishable from magic is insufficiently advanced.',
#  'Anyone can hold the helm when the sea is calm.',
#  'Anyone can make history. Only a great man can write it.',
#  'Anyone can make mistakes, but only an idiot persists in his error.',
#  'Anyone may arrange his affairs so that his taxes shall be as low as possible.',
#  'Anyone without a sense of humor is at the mercy of everyone else.',
#  'Anything is easy if you can assimilate it to your collection of models.',
#  'Anything is possible, but only a few things actually happen.',
#  'Appearance VERSUS reality? Appearance IS reality...',
#  'Appearances often are deceiving.',
#  'Apply good consumerism to your love relationships.',
#  'Approach your limits from the safe side.',
#  'Architecture is frozen music.',
#  'Argue for your limitations and sure enough, they are yours.',
#  'Armed with these patterns, we go forward and brilliantly predict... the past.',
#  'Art has no enemy but ignorance.',
#  'Art is a lie that makes us realize the truth.',
#  'Art is never finished, only abandoned.',
#  'Artistic temperament is a disease that afflicts amateurs.',
#  'As a rule, pantheism is only a respectful variety of atheism.',
#  "As average skill increases, it's more difficult to outperform by large margins.",
#  "As far as the question of Martian life, if we don't go, we won't know.",
#  'As is the mother, so is her daughter.',
#  'As life is to live, so love is to give.',
#  'As others hurt and betray us, so are we the perpetrators of pain.',
#  'As silent as the grave.',
#  'As the area of your knowledge grows, so does the perimeter of your ignorance.',
#  'As the body becomes more limited, the soul expands.',
#  'As the question, so the answer.',
#  'As we migrated into Europe we discovered something new, called winter.',
#  'Ask a self-answering question; get a self-questioning answer.',
#  'Ask no questions and you will be told no lies.',
#  'Ask not for whom the bell tolls; it tolls for thee.',
#  "Ask not what's inside your head, but what your head's inside of.",
#  'Ask yourself whether you are happy and you cease to be so.',
#  'Assume the worst, hope for the best, accept reality.',
#  'Assumption is the mother of all screw-ups.',
#  'Astrology is true, but the astrologers cannot find it.',
#  'At 50, everyone has the face he deserves.',
#  'At either end of the social spectrum there lies a leisure class.',
#  'At retirement, human capital falls to zero.',
#  'Attachments fall away like a snake sheds its skin.',
#  'Attack the problem, not each other.',
#  'Avoid unnecessary dependency on large scale, harmful predictions.',
#  'Bad is never good until worse happens.',
#  "Be a good listener 'cause you never learn much from talking.",
#  'Be a light unto the darkness, and curse it not.',
#  'Be agreeable in manner, and resolute in action.',
#  "Be an expert on what's strong, not on what's wrong.",
#  'Be ashamed to die until you have won one victory for humanity.',
#  'Be bold in what you stand for and careful what you fall for.',
#  'Be both a speaker of words and a doer of deeds.',
#  'Be careful what you plug yourself into.',
#  'Be faithful to that which exists nowhere but in yourself.',
#  'Be fearful when others are greedy, and greedy when others are fearful.',
#  'Be good and you will be lonesome.',
#  'Be in the world but not of it.',
#  'Be kind and courteous to everyone.',
#  "Be nice to people on your way up; you'll meet them on your way down.",
#  'Be not anxious about what you have, but about what you are.',
#  'Be organized: This is a euphemism for being efficiently lazy.',
#  'Be sure your ladder of success is leaning against the right wall.',
#  'Be thou familiar, but by no means vulgar.',
#  'Beauty is one of the rare things which do not lead to doubt of God.',
#  'Beauty may have fair leaves, yet bitter fruit.',
#  "Beauty that doesn't make a woman vain makes her very beautiful.",
#  'Become famous for finishing important, difficult tasks.',
#  'Becoming number one is easier than remaining number one.',
#  'Before borrowing money from a friend, decide which you need more.',
#  'Before thirty, men seek disease; after thirty, diseases seek men.',
#  'Before you kill the cat, make arrangements for the mice.',
#  'Begin a lesson with a humorous illustration.',
#  'Being consistent is less important than being happy.',
#  'Being deserving of praise blinds us to flattery.',
#  'Being human involves becoming a burden.',
#  'Being lazy will make you poor, but hard work will make you rich.',
#  'Being on sea, sail; being on land, settle.',
#  'Being part of the tribal mind is part of your evolution.',
#  'Belief in God? An afterlife? I believe in rock...',
#  'Belief in the supernatural reflects a failure of the imagination.',
#  'Belief is not the beginning but the end of all knowledge.',
#  'Believe only half of what you see, and nothing that you hear.',
#  'Best is best cheap.',
#  'Better a cruel truth than a comfortable delusion.',
#  'Better a diamond with a flaw than a pebble without.',
#  'Better a lean peace than a fat victory.',
#  'Better a little loss than a long sorrow.',
#  'Better clean death than dirty life.',
#  'Better late than never.',
#  'Better some of a pudding than none of a pie.',
#  'Better the foot slip than the tongue.',
#  'Better to be ignorant of a matter than half know it.',
#  'Better to be patient on the road than a patient in the hospital.',
#  'Better to be poor and fear the Lord than to be rich and in trouble.',
#  'Better to be the head of an ass than the tail of a horse.',
#  'Better to reign in Hell then serve in Heaven.',
#  'Better untaught than ill taught.',
#  'Between a good reputation and great wealth, choose a good reputation.',
#  'Beware of all enterprises that require new clothes...',
#  'Beware of the man of one book.',
#  'Beware of the man who has no enemies.',
#  'Beware of your wishes: They will probably come true.',
#  'Beware temptation',
#  "Beware those who cannot tell God's will from their own.",
#  "Big brother isn't watching you, you're watching big brother",
#  "Bigger isn't always better, but better will always get bigger.",
#  'Biochemistry is the study of carbon compounds that crawl.',
#  'Blessed is he who expects nothing, for he shall never be disappointed.',
#  'Blessings on him that invented sleep!',
#  'Blinding speed can compensate for a lot of deficiencies.',
#  'Books as well as food nourish and warm people. Books make connections.',
#  'Boredom: The desire for desires.',
#  'Borrowed garments never fit well.',
#  "Bumper sticker: My politics don't fit on a bumper sticker.",
#  'Bureaucracy: A giant mechanism operated by pygmies.',
#  'Business first and pleasure afterwards.',
#  'Business is a combination of war and sport.',
#  'Busy souls have no time to be busybodies.',
#  'But "yes" can mean so many things.',
#  'But how can fame and profit concern a man of genius?',
#  'But in this world nothing is certain but death and taxes.',
#  'But it does move!',
#  'By their fruit you will recognize them. (By their works ye shall know them.)',
#  'Call on God, but row away from the rocks.',
#  'Calling religion a mental illness is really insulting to mentally ill people.',
#  'Can anyone remember when the times were not hard and money not scarce?',
#  'Care is no cure.',
#  'Cast not out the foul water till you bring in the clean.',
#  "Celebrity isn't an achievement in itself.",
#  'Certain actors in history change the world by staging their own defeat.',
#  'Chance favors the prepared mind.',
#  'Chance is perhaps the pseudonym of God when He did not want to sign.',
#  'Change your mind as often as the facts change.',
#  'Character consists of what you do on the third and fourth tries.',
#  'Character is what you are in the dark.',
#  'Charity should be spontaneous. Calculated altruism is an affront.',
#  'Chastity is more a state of mind than of anatomy.',
#  'Chastity is no more a virtue than malnutrition.',
#  'Choice is a terrifying power.',
#  'Choice of words is spontaneous but no accident.',
#  'Choice within constraint is essential; choice without constraint is paralyzing.',
#  'Christianity might be a good thing if anyone ever tried it.',
#  'Circumstances rule men; men do not rule circumstances.',
#  'Civility is a sign of strength, not weakness.',
#  'Civilization is limitless multiplication of unnecessary necessities.',
#  'Civilization is what the neutron bombs are supposed to leave intact.',
#  'Civilization remains a remote ideal.',
#  'Civilizations that make it in the long run must reintegrate into the biosphere.',
#  'Clarity is power.',
#  'Clear thinking requires courage rather than intelligence.',
#  'Cleverness is not wisdom.',
#  "Cloning is unnatural, but unnatural isn't... a synonym for bad.",
#  'Cogito ergo sum. (I think, therefore I am.)',
#  'Collective responsibility brings a lowering of moral standards.',
#  'College is a refuge from hasty judgment.',
#  'Comedy is tragedy plus time.',
#  'Comfort zones are most often expanded through discomfort.',
#  'Command yourself to feel good about yourself.',
#  'Common sense is instinct, and enough of it is genius.',
#  'Common sense is not so common.',
#  'Common sense, in an uncommon degree, is what the world calls wisdom.',
#  'Communication is next to impossible with someone who has no doubts.',
#  'Companionship is often shared loneliness.',
#  'Compensate complexity with simplicity.',
#  'Conceit causes more conversation than wit.',
#  'Conflict is inevitable but not necessarily bad.',
#  'Conflict is not possible without communication.',
#  'Conquer yourself instead of the world.',
#  "Conscience is God's presence in man.",
#  'Conscience makes egotists of us all.',
#  'Consciousness is a full-time job.',
#  'Consciousness is not an emergent property of the universe, but fundamental.',
#  'Consciousness means freedom from attachment.',
#  'Consistency is the last refuge of the unimaginative.',
#  'Consistency is the quality of a stagnant mind.',
#  'Contentment is the smother of invention.',
#  'Contexts serve as (mental) primers.',
#  'Counsel must be followed, not praised.',
#  'Courage is not the absence of fear but the conquest of it.',
#  'Courage is the price life exacts for granting peace.',
#  'Cowards are cruel but the brave love mercy.',
#  'Creation is a mighty joke, but the laugh is at my own expense.',
#  'Creativity, like love, should be diagnosed retrospectively.',
#  'Criticism comes easier than craftsmanship.',
#  "Curiosity is ill manners in another's house.",
#  'Curiosity will conquer fear even more than bravery will.',
#  'Cynicism is an unpleasant way of saying the truth.',
#  'Darkness is cheap.',
#  'De gustibus non es disputandum. (In matters of taste there can be no disputes.)',
#  'Death and taxes may be inevitable, but they should not be simultaneous.',
#  "Death is a self-fulfilling prophecy. You just don't dwell on it.",
#  "Death is every man's final critic. To die well you must live bravely.",
#  'Death is the ultimate low, from which we do not recover.',
#  'Death keeps no calendar.',
#  'Deeds are fruits, words are but leaves.',
#  'Deeds are males, and words are females.',
#  'Degrees and credentials are primarily badges of compliance.',
#  'Delay is preferable to error.',
#  'Delay is the deadliest form of denial.',
#  'Delusion fends off disillusion.',
#  'Democracy is good. I say this because other systems are worse.',
#  'Democracy is the art of running the circus from the monkey cage.',
#  'Democracy is the worst form of government',
#  'Democracy means only that people are sovereign; not that they are infallible.',
#  'Dependable is not the same as accurate.',
#  'Desire unacted is corruption.',
#  'Desires and longings are the root cause of all suffering.',
#  'Details call things into being.',
#  "Did God the designer choose a method designed precisely as if he wasn't there?",
#  'Difficult to find a black cat in a dark room, especially if there is no cat.',
#  'Discontent is the first step in the progress of a man or a nation.',
#  'Discouragement is simply the despair of wounded self-love.',
#  'Discussions of morality must inevitably lead to immoral statements.',
#  'Divine justice, and how it plays out, is perfect.',
#  'Divorce can be a creative experience.',
#  'DNA is not really a thing, it is a memory.',
#  'Do not ask for what you will wish you had not got.',
#  'Do not be angry with me if I tell you the truth.',
#  'Do not beg trouble from the future.',
#  'Do not count your chickens before they are hatched.',
#  'Do not cross a river if it is four feet deep on average.',
#  'Do not handicap your children by making their lives easy.',
#  'Do not try to live forever. You will not succeed.',
#  'Do one thing every day that scares you.',
#  'Do the thing and have the power.',
#  'Do unto others as they would have you do unto them.',
#  'Do what you love, and follow your passion.',
#  "Do you wish people to think well of you? Don't speak well of yourself.",
#  'Doctors do not cry but men do.',
#  'Doctors think many patients are cured who have simply quit in disgust.',
#  'Does this path have a heart?',
#  'Dogs that bark at a distance bite not at hand.',
#  'Doing your best is more important than being the best.',
#  "Dollar-cost average your entire life, you'll beat almost everyone who doesn't.",
#  "Don't be ashamed to say what you are not afraid to think.",
#  "Don't be reckless with other people's hearts.",
#  "Don't believe all you hear, spend all you have, or sleep all you want.",
#  "Don't change a hair for me, not if you care for me.",
#  "Don't confuse mere inconveniences with real problems.",
#  "Don't congratulate yourself too much, or berate yourself either.",
#  "Don't count the days. Make the days count.",
#  "Don't cross the bridge till you get to it.",
#  "Don't die until you're dead.",
#  "Don't do something. Just stand there.",
#  "Don't expect drastic changes fast. Good practices require practice.",
#  "Don't judge a man until you have walked a mile in his shoes.",
#  "Don't let editors edit the life out of your sentences!",
#  "Don't let God laugh alone.",
#  "Don't limit your challenges; challenge your limits.",
#  "Don't look for the right person; be the right person.",
#  "Don't meet troubles half-way.",
#  "Don't outlive your money.",
#  "Don't put anything in writing that you wouldn't want to see in print.",
#  "Don't send your spirit on missions of destruction.",
#  "Don't stop along the way at all. That's illusion too.",
#  "Don't take anything seriously except happiness.",
#  "Don't teach your children what to think; just teach them to think.",
#  "Don't tell me the sky's the limit when there are footprints on the moon.",
#  "Don't think that a house covered with snow has no fire in it.",
#  "Don't use big words for little matters.",
#  "Don't use yesterday as an excuse for not being fine.",
#  "Don't use your powers, let them go.",
#  "Don't Worry, Be Happy.",
#  "Doubt is humble, and that's what man needs to be.",
#  'Draw a circle around your love and hate will walk the line.',
#  'Drawing on my fine command of language, I said nothing.',
#  "Dream as if you'll live forever. Live as if you'll die tomorrow.",
#  'Dry bread at home is better than roast meat abroad.',
#  'Dry socks are far more important than clean underwear.',
#  'During depressions, assets return to their rightful owners.',
#  'During the lows I find hope in knowing another high will come along.',
#  'Each bird loves to hear himself sing.',
#  'Each circumstance is a gift, and in each experience is hidden a treasure.',
#  "Each day can be whatever it is, and it's all right.",
#  'Each of us bears his own Hell.',
#  'Each one of us is an experiment-of-one.',
#  'Each one of us is plugged into a schemata of archetypal patterns.',
#  "Earth is the cradle of reason, but it's impossible to live eternally in cradles.",
#  'Eat to live, and not live to eat.',
#  'Eclipses clearly illuminate numerous features of society.',
#  'Economic compulsion determines ethical perspective.',
#  'Education is a method whereby one acquires a higher grade of prejudice.',
#  'Education is a progressive discovery of our own ignorance.',
#  'Education is a weapon.',
#  'Education is the process of casting false pearls before real swine.',
#  'Education makes a straight cut ditch of a free meandering brook.',
#  'Eighty percent of success is showing up.',
#  'Eliminate any artificial "creativity" processes in the company.',
#  'Empowering your child does not depower you.',
#  'Energy flowing through a system organizes that system into greater complexity.',
#  'Energy flows where attention goes.',
#  'Engineering is the art of knowing how to avoid difficult issues.',
#  'Engineering is the art of making the impossible possible.',
#  'Engineers are the natural enemies of marketing people.',
#  'Enjoy your body. Use it every way you can.',
#  "Enjoy yourself, it's later than you think.",
#  'Envy and mediocrity are an explosive mixture.',
#  'Established technology tends to persist in spite of new technology.',
#  'Eternity is a mere moment, just long enough for a joke.',
#  'Eureka!',
#  "Even if we fail, we'll learn.",
#  "Even the best of friends cannot attend each other's funeral.",
#  'Every 5-7 years, people forget that recessions occur every 5-7 years.',
#  'Every blessing ignored becomes a curse.',
#  'Every cloud has a silver lining.',
#  'Every cubic inch in space is a miracle.',
#  'Every day you add one more day to your history.',
#  'Every exit is an entry somewhere else.',
#  'Every fool aspired to be a knave.',
#  'Every good idea started out as a bad idea.',
#  'Every human is... that profound secret and mystery to every other.',
#  'Every man dies... Not every man truly lives.',
#  'Every man has a right to be conceited until he is successful.',
#  'Every man has two vocations: His own and philosophy.',
#  'Every man is a fool sometimes, and none at all times.',
#  'Every man is all of man.',
#  'Every man is as God made him, ay, and often worse.',
#  'Every man is best known to himself.',
#  'Every man loves what he is good at.',
#  'Every man who takes office in Washington either grows or swells.',
#  'Every mile is two in winter.',
#  'Every minority group in order to survive works harder than usual.',
#  'Every moment is precious. And precarious.',
#  'Every nation has the government it deserves.',
#  'Every new generation is a fresh invasion of savages.',
#  'Every now and then, bite off more than you can chew.',
#  'Every pawn move loosens the position.',
#  'Every person on earth plays a central role in the history of the world.',
#  "Every revolution was first a thought in one man's mind.",
#  'Every saint has a past and every sinner has a future.',
#  'Every single person has his or her divine purpose for being here.',
#  'Every single person you relate to has a completely different culture.',
#  'Every truth starts life as a heresy and ends life as an orthodoxy.',
#  'Every truth that finally wakes up in you changes the rules of your life.',
#  'Every word is like an unnecessary stain on silence and nothingness.',
#  'Everybody has something to conceal.',
#  "Everybody is somebody else's weirdo.",
#  'Everyone does better when everyone does better.',
#  'Everyone in favor of birth control has already been born.',
#  'Everyone is entitled to his own opinion, but not his own facts.',
#  'Everyone is in the best seat.',
#  'Everyone is partly man and partly woman.',
#  'Everyone loves praise. Look hard for ways to give it to them.',
#  'Everyone you meet is fighting a battle you know nothing about.',
#  'Everyone, when they are young, knows what their destiny is.',
#  'Everything bows to success, even grammar.',
#  'Everything changes but change itself.',
#  'Everything has beauty, but not everyone sees it.',
#  'Everything has some value',
#  'Everything I did in my life that was worthwhile I caught hell for.',
#  'Everything in excess! To enjoy the flavor of life, take big bites.',
#  'Everything in the world may be endured except continual prosperity.',
#  'Everything in war is very simple, but the simplest thing is difficult.',
#  'Everything in your universe becomes your teacher.',
#  'Everything should be made as simple as possible, but not simpler.',
#  'Everything takes longer than you think it will.',
#  'Everything tends toward chaos.',
#  'Everything that used to be a sin is now a disease.',
#  'Evil is never intended as evil.',
#  'Evil is the termination of infinite play.',
#  'Evil is... the restriction of all play to one or another finite game.',
#  'Evolution is a theory that accounts for variety, not superiority.',
#  'Examine what is said, not him who speaks.',
#  'Example has more followers than reason.',
#  'Excellence is not an act but a habit.',
#  'Excellent things are hard to come by.',
#  'Exceptions are pernicious because they conceal laws.',
#  'Execute every act of thy life as though it were thy last.',
#  'Expectations are resentment in training.',
#  'Experience is sometimes dangerous.',
#  'Experience is the name everyone gives to their mistakes.',
#  'Experience keeps a dear school, but fools will learn in no other.',
#  'Expert advice is a great comfort, even when it is wrong.',
#  'Explanation is an antagonistic encounter.',
#  'Expressing anger is a form of public littering.',
#  'Extraordinary claims require extraordinary evidence.',
#  'Face reality: Consistently adequate is good enough.',
#  'Facts are meaningless except as part of a system.',
#  'Facts are stubborn things.',
#  'Facts do not cease to exist because they are ignored.',
#  'Fair words and foul play cheat both young and old.',
#  'Fair words make me look to my purse.',
#  'Faith means making a virtue out of not thinking.',
#  'Faith without works is dead.',
#  'Fake news has real consequences!',
#  'Fame is proof that people are gullible.',
#  'Fame is the perfume of heroic deeds.',
#  'Familiarity breeds contempt.',
#  'Fashion: A despot whom the wise ridicule and obey.',
#  'Fate knows best sometimes.',
#  'Fear is interest paid on a debt you may not owe.',
#  'Fear is the result of impurity.',
#  'Fear teaches us in the most graphic terms just what it is we value.',
#  'Feelings are neither good nor bad; they are just indicators.',
#  'Few of us seem to realize that pleasure is not the same as happiness.',
#  'Few people recover from having had a childhood.',
#  'Few, if any, survive their teens.',
#  'Fifty percent of something is better than 100 percent of nothing.',
#  "Figures won't lie, but liars will figure.",
#  'Financial diversification means always having to say you are sorry.',
#  'Find an aim in life before you run out of ammunition.',
#  'Finite play is inherently contradictory; infinite play is paradoxical.',
#  'Fire is a low-temperature phenomenon... in the universe.',
#  'First in time, first in right.',
#  'Flattery is like cologne: To be smelled, but not swallowed.',
#  'Float like a butterfly, sting like a bee.',
#  'Focused action beats brilliance any day.',
#  'Follow your bliss.',
#  'Folly grows without watering.',
#  'Food for thought is no substitute for the real thing.',
#  'Fool me once, shame on you. Fool me twice, shame on me.',
#  'Fools are always at the bottom of the food chain.',
#  "Fools don't attempt suicide; rather, they succeed at it.",
#  'For every credibility gap, there is a gullibility fill.',
#  "For God's sake, stop researching for a while and begin to think.",
#  'For humans, honest is a matter of degree.',
#  'For the love of money is the root of all evil.',
#  'For thee the wonder-working Earth puts forth sweet flowers.',
#  'For us there is only the trying.',
#  'Forbidden fruit is sweet.',
#  'Force has no place where there is need of skill.',
#  'Forget what you know and learn.',
#  'Forget your troubles as easily as you do your blessings.',
#  "Forgive us, for we also know not what we don't.",
#  'Forgive your enemies, but never forget their names.',
#  'Forgiveness is the attribute of the strong.',
#  'Freedom begins between the ears.',
#  'Freedom is its own punishment.',
#  'Freedom is nothing else but the chance to do better.',
#  'Freedom is slavery. Ignorance is strength. War is peace.',
#  'Freedom is the recognition of necessity.',
#  'Freedom is the right to be wrong, not the right to do wrong.',
#  'Freedom, not safety, is the highest good.',
#  'Friends may come and go, but enemies accumulate.',
#  'Friendship is one mind in two bodies.',
#  'From each according to his abilities, to each according to his needs.',
#  'From error to error, one discovers the entire truth.',
#  'From fanaticism to barbarism is only one step.',
#  'From hearing comes wisdom; from speaking, repentance.',
#  'Fruit ripens not well in the shade.',
#  'Furious activity is no substitute for understanding.',
#  'Genius is 1% inspiration and 99% perspiration.',
#  'Genius is born, not paid.',
#  'Genuine travel has no destination.',
#  'Geologic time is measured by mass extinctions.',
#  'Get up one time more than you are knocked down.',
#  'Getting old is giving up one damn thing after another.',
#  'Ghosts are the insomniacs among the dead.',
#  "Give me enough medals, and I'll win any war.",
#  'Give religion privilege, and it gets corrupted.',
#  "Given a choice between grief and nothing, I'd choose grief.",
#  'Glory is fleeting, but obscurity is forever.',
#  'Glory to the pattern finders. They make sense out of apparent chaos.',
#  "Goals... Plans... They're fantasies, part of a dream world...",
#  'God came to the United States in the form of LSD.',
#  'God complains not, but does what is fitting.',
#  'God does not play dice with the universe.',
#  'God gives us the nuts, but he does not crack them.',
#  'God heals and the doctor takes the fee.',
#  'God is great, too great for me.',
#  'God is not all-powerful as he cannot build a wall he cannot jump.',
#  'God is the tangential point between zero and infinity.',
#  'God made the integers; all else is the work of Man.',
#  "God may be subtle, but he isn't plain mean.",
#  'God offers to every mind its choice between truth and repose.',
#  'God sends meat and the devil sends cooks.',
#  'God strikes with his finger, and not with all his arm.',
#  'God walking on Earth is more important than man walking on the Moon.',
#  "God's career would end tomorrow were there no more problems.",
#  "God, it looks like it's going to be you and me for the rest of my life.",
#  "Gold that's put to use more gold begets.",
#  'Good artists borrow. Great artists steal.',
#  'Good behavior is the last refuge of mediocrity.',
#  'Good gift: Someone really wants it, but feels guilty buying it for themselves.',
#  "Good management is knowing what's fundamental to success and what's not.",
#  'Good memories have ill judgements.',
#  'Good men are scanty, make much of one.',
#  'Good poetry and bad poetry look pretty much the same at fifty yards.',
#  'Good teaching is one-fourth preparation and three-fourths theater.',
#  'Good words are worth much, and cost little.',
#  'Good, to forgive; best, to forget.',
#  'Gossip is so tasty, how we love to swallow it!',
#  'Grace is more beautiful than beauty.',
#  'Gratitude is a lively sense of future favors.',
#  'Gratitude is the memory of the heart.',
#  'Great achievements require relatively few ideas and even less men.',
#  'Great acts are made up of small deeds.',
#  "Great art is indefinable but that's all right; it exists anyway.",
#  'Great art is never perfect; perfect art is never great.',
#  'Great blunders are often made, like large ropes, of a multitude of fibers.',
#  'Great intellects are skeptical.',
#  'Great love and great achievements involve great risk.',
#  'Great men have great faults.',
#  'Great minds have purposes; others have wishes.',
#  'Greater qualities are necessary to bear good fortune than bad.',
#  'Grown men do not need leaders.',
#  'Growth for the sake of growth is the ideology of the cancer cell.',
#  'Half the truth is often a great lie.',
#  'Half the world knows not how the other half lives.',
#  'Happiness equals reality minus expectations.',
#  'Happiness is a perpetual possession of being well deceived.',
#  "Happiness isn't something you experience; it's something you remember.",
#  'Happy folks do not make history.',
#  'Happy is he that is happy in his children.',
#  'Happy is the man who becomes wise, who gains understanding.',
#  'Hard reality has a way of cramping your style.',
#  'Haste makes waste.',
#  'Hasten slowly.',
#  'Hate is a disease, and tolerance is the cure.',
#  'Hate stirs up trouble, but love overlooks all offenses.',
#  'Hate the sin and love the sinner.',
#  'Hating people is like burning down your own house to get rid of a rat.',
#  'Hatred is blind, as well as love.',
#  'Hatred is never ended by hatred but by love.',
#  'Have no friends not equal to yourself.',
#  'Have the courage to be honest with yourself.',
#  "Have you ever gone out to see how much fun you'd be to be with?",
#  'Having been poor is no shame, but being ashamed of it, is.',
#  'Having made one lie, he is fain to make more to maintain it.',
#  'Having nothing, nothing can he lose.',
#  'Having the fewest wants, I am nearest to the gods.',
#  'He bears misery best that hides it most.',
#  'He cannot be good that knows not why he is good.',
#  'He cries wine and sells vinegar.',
#  'He has not acquired a fortune; the fortune has acquired him.',
#  'He has slept well that remembers not he has slept ill.',
#  'He is a good orator who convinces himself.',
#  'He is now rising from affluence to poverty.',
#  'He is poor indeed that can promise nothing.',
#  'He is the best of men who dislikes power.',
#  'He jests at scars who never felt a wound.',
#  'He knows not how to know who knows not also how to unknow.',
#  'He knows not what good is who has not tried what evil is.',
#  'He laughs best that laughs last.',
#  'He loses his thanks who promises and delays.',
#  'He loses indeed that loses at last.',
#  'He loses nothing who keeps God for his friend.',
#  'He or she who would gather roses must not fear thorns.',
#  'He played the king as if afraid someone else would play the ace.',
#  'He sits not sure that sits too high.',
#  'He that bringeth a present, findeth the door open.',
#  'He that brings good news knocks hard.',
#  'He that cannot abide a bad market deserves not a good one.',
#  'He that cannot pay let him pray.',
#  'He that counts all costs will never put plow in the earth.',
#  'He that falls in love with himself, will have no rivals.',
#  'He that fears you present will hate you absent.',
#  'He that has a full purse never wanted a friend.',
#  'He that has no money needs no purse.',
#  'He that hurts another hurts himself.',
#  'He that is born a fool is never cured.',
#  'He that is carried down the stream need not row.',
#  'He that is fallen cannot help him that is down.',
#  'He that is giddy thinks the world turns round.',
#  'He that knows little soon repeats it.',
#  'He that knows nothing doubts nothing.',
#  'He that lends, gives.',
#  'He that lies upon the ground can fall no lower.',
#  'He that lives most, dies most.',
#  'He that lives well is learned enough.',
#  'He that lives wickedly can hardly die honestly.',
#  'He that loves well sees afar off.',
#  'He that makes a thing too fine, breaks it.',
#  'He that seeks finds.',
#  'He that sleeps with dogs must rise up with fleas.',
#  'He that speaks to a fool, talks to himself.',
#  'He that stays in the valley shall never get over the hill.',
#  'He that steals honey should beware of the sting.',
#  'He that will be served, must be patient.',
#  'He that will enter into Paradise must have a good key.',
#  'He was meant for a gentleman, but was spoilt in the making.',
#  'He who angers you, conquers you.',
#  'He who can, does. He who cannot, teaches.',
#  'He who defines the terms wins the argument.',
#  'He who fears the unknown may one day flee from his own backside.',
#  'He who fights and runs away lives to fight another day.',
#  'He who gives promptly gives twice.',
#  'He who has a WHY to live for can bear with almost any HOW.',
#  'He who hesitates is lost.',
#  'He who hesitates is sometimes saved.',
#  'He who knows others is wise. He who knows himself is enlightened.',
#  'He who knows that enough is enough will always have enough.',
#  'He who knows, does not speak. He who speaks, does not know.',
#  'He who opens a school door, closes a prison.',
#  'He who owes is in all wrong.',
#  'He who sees much can endure much.',
#  'He who slings mud generally loses ground.',
#  'He who wonders discovers that this in itself is wonder.',
#  'He who would climb the ladder must begin at the bottom.',
#  "He's poor as Job, and not so patient.",
#  'Health follows a change in mindset, just as in the case for placebos.',
#  'Hearts may agree, though heads differ.',
#  'Heaven does not worth according to human justice.',
#  'Heaven has no regard for physical comfort.',
#  'Heaven is to be at peace with all things.',
#  'Heaven is under our feet as well as over our heads.',
#  'Hell is always open.',
#  'Hell is wherever heaven is not.',
#  'Her head looks as if it had worn out two bodies.',
#  'Here it is standing: Atoms with consciousness; matter with curiosity.',
#  'Here lies a good fellow who spent his life while he had it.',
#  'Hey, everything goes wrong every minute. What you do is fix it.',
#  'Higher technology does not necessarily equate to higher anything else.',
#  'Historians are gossips who tease the dead.',
#  'History develops, art stands still.',
#  'History is any succession of events seen with the effect of posteriority.',
#  'History is not a spectator sport.',
#  'History is written by the survivors.',
#  'History knows no resting places and no plateaus.',
#  'History may not repeat but sometimes it rhymes.',
#  'History will be kind to me for I intend to write it.',
#  'Home is home, though it be never so homely.',
#  'Home is the sailor, home from the sea...',
#  "Home is where I want to be, but I guess I'm already there.",
#  'Honor lies in honest toil.',
#  'Hope is not a great investment strategy.',
#  "Hope is the poor man's bread.",
#  'Hope keeps man alive.',
#  'Hot love is soon cold.',
#  'Hot tempers cause arguments, but patience brings peace.',
#  'Houston, Tranquillity Base here. The Eagle has landed.',
#  "How are you going to shape the future if you don't know the past?",
#  'How beautiful it is to do nothing, and then rest afterward.',
#  'How can I know what I think until I see what I say?',
#  'How can so many take The Amazing Journey and not be amazed?',
#  'How do we acquire wisdom along with all these shiny things?',
#  'How does a project get to be a year late? One day at a time.',
#  'How long does it take to learn that violence begets violence?',
#  'Human beings live longer and better when they enjoy what they do.',
#  "Human rationality isn't a scientist, it's a lawyer.",
#  'Humans are captivated by stories, but largely oblivious to data.',
#  "Humans are communications junkies. We just can't get enough.",
#  'Humans are motivated by what has been done for them lately.',
#  "Humans can't think randomly.",
#  'Humans need simple answers for complex problems.',
#  'Humble hearts have humble desires.',
#  'Humility is a virtue when you have no other.',
#  'Humility to genius is as an extinguisher to a candle.',
#  "Humor is a drug which it's the fashion to abuse.",
#  'Humor is by far the most significant activity of the human brain.',
#  'Hunger is not caused by scarcity of food but scarcity of democracy.',
#  'Hunger is the best sauce.',
#  'Hunger knows no friend.',
#  'Hurt people hurt people.',
#  'Hypocrites are real atheists.',
#  'I am a deeply religious non-believer. This is a somewhat new kind of religion.',
#  "I am an enemy of the State. But isn't everyone?",
#  'I am becoming more energy than matter.',
#  'I am convinced the desire to formulate truths is a virulent disease.',
#  'I am cured of my illness; I am healed with my illness.',
#  'I am exactly where I am supposed to be.',
#  'I am glad I will not be young in a future without wilderness.',
#  'I am looking for an honest man.',
#  'I am not this thought.',
#  'I am the story I tell myself.',
#  'I am two fools, I know, for loving, and for saying so.',
#  'I believe in getting into hot water; it keeps you clean.',
#  'I believe in nothing that I cannot touch, kiss, embrace...',
#  'I can believe anything, provided it is incredible.',
#  "I can't afford to waste my time making money.",
#  "I can't complain, but sometimes I still do.",
#  "I cannot and will not cut my conscience to fit this year's fashions.",
#  "I cannot be alone; it's not possible.",
#  'I cannot prove this statement is true.',
#  'I cannot tell you my truth until you stop telling me yours.',
#  "I couldn't possibly fail to disagree with you less.",
#  'I do not believe in personal immortality; it seems so unnecessary.',
#  'I do not know myself and God forbid that I should.',
#  "I don't gamble. There are other ways to win at life.",
#  "I don't know, I don't care, and it doesn't make any difference.",
#  "I don't make the rules, Gil, I only play the game.",
#  "I don't see why any system of beliefs deserves respect simply because it exists.",
#  "I don't think comedy is an escape from tragedy. They are both life.",
#  "I don't want to make money. I just want to be wonderful.",
#  'I dream things that never were; and I say "Why not?',
#  'I fear explanations explanatory of things explained.',
#  'I find great humor in the fact that we ever take ourselves seriously.',
#  'I forgive and quite forget old faults.',
#  'I found Rome a city of bricks and left it a city of marble.',
#  'I have been a lucky man. But someone has to be.',
#  'I have lost all and found myself.',
#  'I have met my hero, and he is me.',
#  "I have never been hurt by anything I didn't say.",
#  'I have never let my schooling interfere with my education.',
#  'I have never, ever seen God come through the front door.',
#  'I have no special talents. I am only passionately curious.',
#  'I have nothing to say, and I am saying it.',
#  'I have often regretted my speech, never my silence.',
#  'I have promises to keep, and miles to go before I sleep.',
#  'I have with me two gods, Persuasion and Compulsion.',
#  'I know what I know, but I will keep it to myself.',
#  'I like being single. I am always there when I need me.',
#  "I might make you feel, but I can't make you think.",
#  'I never know how much of what I say is true.',
#  'I never think of the future. It comes soon enough.',
#  'I never tried quitting, and I never quit trying.',
#  "I never wish for anyone's death, but read a few obituaries with a chuckle.",
#  'I only know what I read in the papers.',
#  'I prefer rogues to imbeciles, because they sometimes take a rest.',
#  'I put up my thumb... And it blotted out the planet Earth.',
#  'I realized something about perfection... It comes only with time.',
#  'I respect faith, but doubt is what gets you an education.',
#  'I saw that, finally, my responsibility was to work on myself.',
#  'I say little but think the more.',
#  'I seem to be a verb.',
#  'I strive to be brief but I become obscure.',
#  'I think time is a merciless thing.',
#  'I touch the future. I teach.',
#  'I tremble for my country when I reflect that God is just.',
#  'I try not to break the rules but merely to test their elasticity.',
#  "I understand why you are confused. You're thinking too much.",
#  'I used to be disgusted, now I find I am just amused.',
#  'I wanted to do it just as he did; so I began to learn.',
#  'I wasted time and now doth time waste me.',
#  'I will do nothing for you that you will not do for your Self.',
#  "I wish I didn't know now what I didn't know then.",
#  'I would consider it an honor to be fossilized.',
#  'I would like to know what I was fencing in and what I was fencing out.',
#  'I would rather be the first man here than the second in Rome.',
#  'I [am] a channel through which music emerges from the chaos of noise.',
#  "I'd much rather see lube oil running out of a bearing than metal particles.",
#  "I'll meet you... on the dark side... of the moon...",
#  "I'm against a homogenized society because I want the cream to rise.",
#  "I'm always doing that which I cannot do, in order that I may learn how to do it.",
#  "I'm an idealist. I don't know where I'm going, but I'm on my way!",
#  "I'm running out of cheeks to turn.",
#  "I've finally become what I had merely intended to seem.",
#  "If a camel flies, no one laughs if it doesn't get very far.",
#  'If a cat has nine lives, a lie has ninety-nine.',
#  'If a document is over two pages long, few people will ever read it.',
#  'If a fool persists in his folly he shall become wise.',
#  "If a guy is over 25% jerk, he's in trouble.",
#  'If a man has talent and cannot use it, he has failed.',
#  'If a man hears much that a woman says, she is not beautiful.',
#  "If a person can't communicate, the very least he can do is to shut up!",
#  'If a plant grows in abundance, it is a plant of virtue.',
#  'If a string has one end, then it has another end.',
#  "If a thing's worth doing, it is worth doing badly.",
#  'If anything can go wrong, it will.',
#  'If anything is sacred, the human body is sacred.',
#  "If at first you don't succeed, try, try again.",
#  'If Christ were here now there is one thing he would not be',
#  'If everybody was satisfied with himself, there would be no heroes.',
#  'If God did not exist, it would be necessary to invent him.',
#  'If guns are outlawed, only the government will have guns.',
#  'If happiness is in your destiny, you need not be in a hurry.',
#  'If he works for you, you work for him.',
#  'If I cannot bend Heaven, I shall move Hell.',
#  ...]

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus).todense()

# %%
def similCompute(X, y):
    simil = []
    for i in range(X.shape[0]):
        row = X[i, :]
        if np.linalg.norm(y) == 0:
            return np.random.randint(X.shape[0])
        sim = np.dot(row, y.T)/(np.linalg.norm(row) * np.linalg.norm(y))
        simil.append(sim)
    return np.argmax(simil)

# %%
text ="I lost my happyness"
y = vectorizer.transform([text]).todense()
print(np.linalg.norm(y))
idx = similCompute(X, y)
quote = corpus[idx]
print(quote)
X.shape
# Out:
# 1.0
# He who hesitates is lost.
# (3055, 4372)

# %%
app = Flask(__name__)

# %%
@app.route('/')
def index():
    return render_template("index.html")

@app.route('/compute', methods=['POST'])
def parse_text():
    text = request.form.get("text")
    if len(text) > 0:
        y = vectorizer.transform([text]).todense()
        idx = similCompute(X, y)
        quote = corpus[idx]
    else:
        quote = ""
    obj = [{"quote": quote}]
    return jsonify(obj)

# %%
port = int(os.environ.get('PORT', 5000))
if __name__ == "__main__":
    #app.run(host='0.0.0.0', port = port)
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '0.23.1'
